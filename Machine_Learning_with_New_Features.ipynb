# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from datetime import date
from functools import reduce
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tqdm.notebook import tqdm

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data

# %%
PATH_TO_GAME_LOGS = './datasets/retro_sheet_gls/'

def get_game_logs(game_log_dir=PATH_TO_GAME_LOGS):
    """Function to get game log"""
    
    def generate_date(date_of_game):
        """Helper function that parses a game id for the date"""
        
        date_of_game = str(date_of_game)
        
        # Parse the date
        year = int(date_of_game[0:4])
        month = int(date_of_game[4:6])
        day = int(date_of_game[6:8])
        
        return date(year, month, day)
    
    dfs = []
    for file in os.listdir(game_log_dir):
        df = pd.read_csv(os.path.join(game_log_dir, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Date']), axis=1)
        dfs.append(df)
    return pd.concat(dfs)

# %%
game_logs = get_game_logs()
game_logs
# Out:
#             Date  Number of game  Day Visiting Team Visiting Team League  \
# 0     2014-03-22               0  Sat           LAN                   NL
# 1     2014-03-23               0  Sun           LAN                   NL
# 2     2014-03-30               0  Sun           LAN                   NL
# 3     2014-03-31               0  Mon           SEA                   AL
# 4     2014-03-31               0  Mon           BOS                   AL
# ...          ...             ...  ...           ...                  ...
# 2424  2019-09-29               0  Sun           DET                   AL
# 2425  2019-09-29               0  Sun           MIN                   AL
# 2426  2019-09-29               0  Sun           OAK                   AL
# 2427  2019-09-29               0  Sun           NYA                   AL
# 2428  2019-09-29               0  Sun           TBA                   AL
#
#       Visiting Team Game Number Home Team Home Team League  \
# 0                             1       ARI               NL
# 1                             2       ARI               NL
# 2                             3       SDN               NL
# 3                             1       ANA               AL
# 4                             1       BAL               AL
# ...                         ...       ...              ...
# 2424                        161       CHA               AL
# 2425                        162       KCA               AL
# 2426                        162       SEA               AL
# 2427                        162       TEX               AL
# 2428                        162       TOR               AL
#
#       Home Team Game Number  Visiting Team Score  Home Team Score  \
# 0                         1                    3                1
# 1                         2                    7                5
# 2                         1                    1                3
# 3                         1                   10                3
# 4                         1                    1                2
# ...                     ...                  ...              ...
# 2424                    161                    3                5
# 2425                    162                    4                5
# 2426                    162                    1                3
# 2427                    162                    1                6
# 2428                    162                    3                8
#
#       Length of Game (outs) Time of Game (Day/Night) Completion Information  \
# 0                        54                        N                    NaN
# 1                        54                        D                    NaN
# 2                        51                        N                    NaN
# 3                        54                        N                    NaN
# 4                        51                        D                    NaN
# ...                     ...                      ...                    ...
# 2424                     51                        D                    NaN
# 2425                     52                        D                    NaN
# 2426                     51                        D                    NaN
# 2427                     51                        D                    NaN
# 2428                     51                        D                    NaN
#
#       Forfeit Information Protest Information Park ID  Attendance  \
# 0                     NaN                 NaN   SYD01     38266.0
# 1                     NaN                 NaN   SYD01     38079.0
# 2                     NaN                 NaN   SAN02     45567.0
# 3                     NaN                 NaN   ANA01     44152.0
# 4                     NaN                 NaN   BAL12     46685.0
# ...                   ...                 ...     ...         ...
# 2424                  NaN                 NaN   CHI12     19534.0
# 2425                  NaN                 NaN   KAN06     17875.0
# 2426                  NaN                 NaN   SEA03     16819.0
# 2427                  NaN                 NaN   ARL02     47144.0
# 2428                  NaN                 NaN   TOR02     25738.0
#
#       Length of Game (minutes) Visiting Team Line Score Home Team Line Score  \
# 0                          169                 10200000            000001000
# 1                          241                102021100            000000014
# 2                          169                    10000            00000003x
# 3                          197                 10001206            201000000
# 4                          173                   100000            01000010x
# ...                        ...                      ...                  ...
# 2424                       157                101000001            10000400x
# 2425                       160                300010000            100200011
# 2426                       172                000000001            20001000x
# 2427                       167                001000000            10202100x
# 2428                       187                000100020            20030120x
#
#       Visiting Team At-bats  Visiting Team Hits  Visiting Team Doubles  \
# 0                        33                   5                      2
# 1                        34                  13                      3
# 2                        31                   4                      0
# 3                        36                  11                      4
# 4                        36                   9                      2
# ...                     ...                 ...                    ...
# 2424                     31                   7                      1
# 2425                     32                   6                      1
# 2426                     30                   3                      1
# 2427                     30                   3                      0
# 2428                     36                   9                      3
#
#       Visiting Team Triples  Visiting Team Homeruns  Visiting Team RBIs  \
# 0                         0                       1                   3
# 1                         0                       0                   6
# 2                         0                       0                   1
# 3                         2                       1                  10
# 4                         0                       1                   1
# ...                     ...                     ...                 ...
# 2424                      0                       2                   3
# 2425                      0                       3                   4
# 2426                      0                       0                   1
# 2427                      0                       1                   1
# 2428                      0                       1                   3
#
#       Visiting Team Sacrifice Hits  Visiting Team Sacrifice Flies  \
# 0                                0                              0
# 1                                1                              2
# 2                                0                              0
# 3                                0                              1
# 4                                0                              0
# ...                            ...                            ...
# 2424                             0                              0
# 2425                             0                              0
# 2426                             0                              0
# 2427                             0                              0
# 2428                             0                              0
#
#       Visiting Team Hit-by-pitch  Visiting Team Walks  \
# 0                              1                    3
# 1                              2                    8
# 2                              0                    3
# 3                              0                    8
# 4                              1                    3
# ...                          ...                  ...
# 2424                           0                    3
# 2425                           1                    0
# 2426                           0                    4
# 2427                           0                    1
# 2428                           0                    1
#
#       Visiting Team Intentional Walks  Visiting Team Strikeouts  \
# 0                                   0                        11
# 1                                   0                         7
# 2                                   0                         9
# 3                                   1                        11
# 4                                   0                         6
# ...                               ...                       ...
# 2424                                0                         8
# 2425                                0                         8
# 2426                                0                         8
# 2427                                0                        13
# 2428                                0                        10
#
#       Visiting Team Stolen Bases  Visiting Team Caught Stealing  \
# 0                              0                              0
# 1                              1                              0
# 2                              0                              0
# 3                              1                              1
# 4                              0                              0
# ...                          ...                            ...
# 2424                           1                              0
# 2425                           0                              0
# 2426                           1                              0
# 2427                           0                              0
# 2428                           1                              0
#
#       Visiting Team Grounded into DP  \
# 0                                  0
# 1                                  1
# 2                                  0
# 3                                  0
# 4                                  0
# ...                              ...
# 2424                               2
# 2425                               0
# 2426                               0
# 2427                               0
# 2428                               0
#
#       Visiting Team Awarded First Base due to CI  Visiting Team Left on Base  \
# 0                                              0                           7
# 1                                              0                          13
# 2                                              0                           6
# 3                                              0                           8
# 4                                              0                          12
# ...                                          ...                         ...
# 2424                                           0                           4
# 2425                                           0                           2
# 2426                                           0                           6
# 2427                                           0                           3
# 2428                                           0                           7
#
#       Visiting Team Pitchers Used  Visiting Team Individual Earned Runs  \
# 0                               4                                     1
# 1                               8                                     5
# 2                               4                                     2
# 3                               5                                     2
# 4                               2                                     2
# ...                           ...                                   ...
# 2424                            4                                     4
# 2425                            6                                     5
# 2426                            5                                     3
# 2427                            6                                     4
# 2428                            6                                     8
#
#       Visiting Team Earned Runs  Visiting Team Wild Pitches  \
# 0                             1                           1
# 1                             5                           0
# 2                             2                           0
# 3                             2                           2
# 4                             2                           0
# ...                         ...                         ...
# 2424                          4                           1
# 2425                          5                           0
# 2426                          3                           1
# 2427                          4                           0
# 2428                          8                           1
#
#       Visiting Team Balks  Visiting Team Putouts  Visiting Team Assists  \
# 0                       0                     27                     13
# 1                       0                     27                      4
# 2                       0                     24                     12
# 3                       0                     27                      5
# 4                       0                     24                     11
# ...                   ...                    ...                    ...
# 2424                    0                     24                      7
# 2425                    0                     25                      8
# 2426                    0                     24                      6
# 2427                    0                     24                      8
# 2428                    0                     24                      4
#
#       Visiting Team Errors  Visiting Team Passed Balls  \
# 0                        1                           0
# 1                        1                           0
# 2                        2                           0
# 3                        1                           0
# 4                        0                           0
# ...                    ...                         ...
# 2424                     1                           0
# 2425                     0                           0
# 2426                     0                           0
# 2427                     2                           0
# 2428                     0                           0
#
#       Visiting Team Double Plays  Visiting Team Triple Plays  \
# 0                              0                           0
# 1                              2                           0
# 2                              2                           0
# 3                              0                           0
# 4                              2                           0
# ...                          ...                         ...
# 2424                           1                           0
# 2425                           0                           0
# 2426                           0                           0
# 2427                           2                           0
# 2428                           0                           0
#
#       Home Team At-bats  Home Team Hits  Home Team Doubles  Home Team Triples  \
# 0                    33               5                  1                  0
# 1                    35               8                  0                  0
# 2                    27               5                  0                  0
# 3                    34               6                  1                  0
# 4                    28               6                  0                  0
# ...                 ...             ...                ...                ...
# 2424                 28               4                  2                  0
# 2425                 33               9                  3                  1
# 2426                 31               7                  2                  0
# 2427                 31              10                  1                  0
# 2428                 35              11                  4                  0
#
#       Home Team Homeruns  Home Team RBIs  Home Team Sacrifice Hits  \
# 0                      0               1                         0
# 1                      1               5                         0
# 2                      1               3                         2
# 3                      1               3                         0
# 4                      1               1                         0
# ...                  ...             ...                       ...
# 2424                   1               4                         0
# 2425                   1               5                         0
# 2426                   1               3                         0
# 2427                   0               4                         0
# 2428                   2               8                         0
#
#       Home Team Sacrifice Flies  Home Team Hit-by-pitch  Home Team Walks  \
# 0                             0                       0                2
# 1                             0                       0                8
# 2                             0                       0                4
# 3                             0                       1                1
# 4                             0                       0                1
# ...                         ...                     ...              ...
# 2424                          0                       3                1
# 2425                          1                       0                3
# 2426                          0                       0                5
# 2427                          1                       1                4
# 2428                          0                       1                3
#
#       Home Team Intentional Walks  Home Team Strikeouts  \
# 0                               0                    10
# 1                               0                     8
# 2                               0                    10
# 3                               0                    13
# 4                               0                     9
# ...                           ...                   ...
# 2424                            0                    12
# 2425                            0                     7
# 2426                            0                     7
# 2427                            0                     6
# 2428                            0                     9
#
#       Home Team Stolen Bases  Home Team Caught Stealing  \
# 0                          0                          0
# 1                          0                          0
# 2                          1                          0
# 3                          1                          0
# 4                          0                          0
# ...                      ...                        ...
# 2424                       0                          0
# 2425                       0                          0
# 2426                       0                          0
# 2427                       3                          0
# 2428                       2                          0
#
#       Home Team Grounded into DP  Home Team Awarded First Base due to CI  \
# 0                              0                                       0
# 1                              2                                       0
# 2                              2                                       0
# 3                              0                                       0
# 4                              2                                       0
# ...                          ...                                     ...
# 2424                           1                                       0
# 2425                           0                                       0
# 2426                           0                                       0
# 2427                           2                                       0
# 2428                           0                                       0
#
#       Home Team Left on Base  Home Team Pitchers Used  \
# 0                          7                        5
# 1                         11                        6
# 2                          6                        5
# 3                          6                        5
# 4                          3                        5
# ...                      ...                      ...
# 2424                       3                        6
# 2425                       7                        4
# 2426                       9                        7
# 2427                       7                        2
# 2428                       7                        5
#
#       Home Team Individual Earned Runs  Home Team Earned Runs  \
# 0                                    3                      3
# 1                                    6                      6
# 2                                    1                      1
# 3                                    9                      9
# 4                                    1                      1
# ...                                ...                    ...
# 2424                                 3                      3
# 2425                                 4                      4
# 2426                                 1                      1
# 2427                                 1                      1
# 2428                                 3                      3
#
#       Home Team Wild Pitches  Home Team Balks  Home Team Putouts  \
# 0                          1                0                 27
# 1                          1                0                 27
# 2                          1                0                 27
# 3                          0                0                 27
# 4                          0                0                 27
# ...                      ...              ...                ...
# 2424                       0                0                 27
# 2425                       0                0                 27
# 2426                       4                0                 27
# 2427                       0                0                 27
# 2428                       0                0                 27
#
#       Home Team Assists  Home Team Errors  Home Team Passed Balls  \
# 0                    10                 1                       0
# 1                    15                 3                       0
# 2                    10                 0                       0
# 3                     7                 1                       0
# 4                    13                 0                       0
# ...                 ...               ...                     ...
# 2424                 15                 0                       0
# 2425                  4                 0                       0
# 2426                  8                 0                       0
# 2427                  3                 0                       0
# 2428                 10                 1                       0
#
#       Home Team Double Plays  Home Team Triple Plays Home Plate Umpire ID  \
# 0                          0                       0             welkt901
# 1                          1                       0             scotd901
# 2                          0                       0             culbf901
# 3                          0                       0             westj901
# 4                          0                       0             demud901
# ...                      ...                     ...                  ...
# 2424                       2                       0             morag901
# 2425                       1                       0             libkj901
# 2426                       0                       0             hudsm901
# 2427                       0                       0             bakej902
# 2428                       1                       0             nelsj901
#
#      Home Plate Umpire Name 1B Umpire ID   1B Umpire Name 2B Umpire ID  \
# 0                 Tim Welke     scotd901       Dale Scott     diazl901
# 1                Dale Scott     diazl901         Laz Diaz     carlm901
# 2          Fieldin Culbreth     gonzm901   Manny Gonzalez     reynj901
# 3                  Joe West     fostm901     Marty Foster     drakr901
# 4               Dana DeMuth     kulpr901        Ron Kulpa     hicke901
# ...                     ...          ...              ...          ...
# 2424           Gabe Morales     segac901      Chris Segal     mealj901
# 2425             John Libka     hicke901        Ed Hickox     torrc901
# 2426          Marvin Hudson     herna901  Angel Hernandez     fairc901
# 2427           Jordan Baker     tosia901        Alex Tosi     cedeg901
# 2428            Jeff Nelson     hamaa901      Adam Hamari     diazl901
#
#        2B Umpire Name 3B Umpire ID  3B Umpire Name LF Umpire ID  \
# 0            Laz Diaz     carlm901    Mark Carlson          NaN
# 1        Mark Carlson     welkt901       Tim Welke          NaN
# 2        Jim Reynolds     barbs901     Sean Barber          NaN
# 3           Rob Drake     porta901     Alan Porter          NaN
# 4           Ed Hickox     barrl901   Lance Barrett          NaN
# ...               ...          ...             ...          ...
# 2424      Jerry Meals     kulpr901       Ron Kulpa          NaN
# 2425    Carlos Torres     nauep901     Paul Nauert          NaN
# 2426   Chad Fairchild     blakr901    Ryan Blakney          NaN
# 2427  Gary Cederstrom     johna901  Adrian Johnson          NaN
# 2428         Laz Diaz     randt901   Tony Randazzo          NaN
#
#      LF Umpire Name RF Umpire ID RF Umpire Name Visiting Team Manager ID  \
# 0            (none)          NaN         (none)                 mattd001
# 1            (none)          NaN         (none)                 mattd001
# 2            (none)          NaN         (none)                 mattd001
# 3            (none)          NaN         (none)                 mccll001
# 4            (none)          NaN         (none)                 farrj001
# ...             ...          ...            ...                      ...
# 2424         (none)          NaN         (none)                 gardr001
# 2425         (none)          NaN         (none)                 baldr001
# 2426         (none)          NaN         (none)                 melvb001
# 2427         (none)          NaN         (none)                 boona001
# 2428         (none)          NaN         (none)                 cashk001
#
#      Visiting Team Manager Name Home Team Manager ID Home Team Manager Name  \
# 0                 Don Mattingly             gibsk001            Kirk Gibson
# 1                 Don Mattingly             gibsk001            Kirk Gibson
# 2                 Don Mattingly             blacb001            Buddy Black
# 3               Lloyd McClendon             sciom001          Mike Scioscia
# 4                  John Farrell             showb801         Buck Showalter
# ...                         ...                  ...                    ...
# 2424             Ron Gardenhire             rentr001          Rich Renteria
# 2425             Rocco Baldelli             yoste001               Ned Yost
# 2426                 Bob Melvin             servs002          Scott Servais
# 2427                Aaron Boone             woodc001         Chris Woodward
# 2428                 Kevin Cash             montc001        Charlie Montoyo
#
#      Winning Pitcher ID Winning Pitcher Name Losing Pitcher ID  \
# 0              kersc001      Clayton Kershaw          milew001
# 1              ryu-h001         Hyun-Jin Ryu          cahit001
# 2              thayd001          Dale Thayer          wilsb001
# 3              hernf002      Felix Hernandez          weavj003
# 4              britz001         Zack Britton          lestj001
# ...                 ...                  ...               ...
# 2424           cordj001        Jimmy Cordero          turns003
# 2425           kenni001          Ian Kennedy          gratb002
# 2426           mcclr001       Reggie McClain          roart001
# 2427           lynnl001           Lance Lynn          tanam001
# 2428           buchc001        Clay Buchholz          snelb001
#
#      Losing Pitcher Name Saving Pitcher ID Saving Pitcher Name  \
# 0             Wade Miley          jansk001       Kenley Jansen
# 1          Trevor Cahill               NaN              (none)
# 2           Brian Wilson          streh001       Huston Street
# 3           Jered Weaver               NaN              (none)
# 4             Jon Lester          huntt002        Tommy Hunter
# ...                  ...               ...                 ...
# 2424    Spencer Turnbull          herrk001      Kelvin Herrera
# 2425    Brusdar Graterol               NaN              (none)
# 2426        Tanner Roark          bassa001        Anthony Bass
# 2427     Masahiro Tanaka               NaN              (none)
# 2428         Blake Snell               NaN              (none)
#
#      Game Winning RBI Batter ID Game WInning RBI Batter Name  \
# 0                      ethia001                 Andre Ethier
# 1                      ethia001                 Andre Ethier
# 2                      denoc001               Chris Denorfia
# 3                      almoa001              Abraham Almonte
# 4                      cruzn002                  Nelson Cruz
# ...                         ...                          ...
# 2424                   jimee001                 Eloy Jimenez
# 2425                   philb002               Brett Phillips
# 2426                   seagk001                  Kyle Seager
# 2427                        NaN                       (none)
# 2428                   smoaj001                 Justin Smoak
#
#      Visiting Team Starting Pitcher ID Visiting Team Starting Pitcher Name  \
# 0                             kersc001                     Clayton Kershaw
# 1                             ryu-h001                        Hyun-Jin Ryu
# 2                             ryu-h001                        Hyun-Jin Ryu
# 3                             hernf002                     Felix Hernandez
# 4                             lestj001                          Jon Lester
# ...                                ...                                 ...
# 2424                          turns003                    Spencer Turnbull
# 2425                          perem004                        Martin Perez
# 2426                          roart001                        Tanner Roark
# 2427                          greec003                          Chad Green
# 2428                          snelb001                         Blake Snell
#
#      Home Team Starting Pitcher ID Home Team Starting Pitcher Name  \
# 0                         milew001                      Wade Miley
# 1                         cahit001                   Trevor Cahill
# 2                         casha001                  Andrew Cashner
# 3                         weavj003                    Jered Weaver
# 4                         tillc001                   Chris Tillman
# ...                            ...                             ...
# 2424                      detwr001                   Ross Detwiler
# 2425                      lopej004                     Jorge Lopez
# 2426                      dunnj002                     Justin Dunn
# 2427                      lynnl001                      Lance Lynn
# 2428                      buchc001                   Clay Buchholz
#
#      Visiting Team Player 1 ID Visiting Team Player 1 Name  \
# 0                     puigy001                 Yasiel Puig
# 1                     gordd002                  Dee Gordon
# 2                     crawc002               Carl Crawford
# 3                     almoa001             Abraham Almonte
# 4                     navad002                 Daniel Nava
# ...                        ...                         ...
# 2424                  reyev001                Victor Reyes
# 2425                  wadel001                LaMonte Wade
# 2426                  semim001               Marcus Semien
# 2427                  lemad001                 DJ LeMahieu
# 2428                  diazy001                  Yandy Diaz
#
#       Visiting Team Player 1 Defensive Position Visiting Team Player 2 ID  \
# 0                                             9                  turnj001
# 1                                             4                  puigy001
# 2                                             7                  puigy001
# 3                                             8                  millb002
# 4                                             9                  pedrd001
# ...                                         ...                       ...
# 2424                                          8                  mercj002
# 2425                                          7                  polaj001
# 2426                                          6                  profj001
# 2427                                          3                  judga001
# 2428                                         10                  phamt001
#
#      Visiting Team Player 2 Name  Visiting Team Player 2 Defensive Position  \
# 0                  Justin Turner                                          4
# 1                    Yasiel Puig                                          9
# 2                    Yasiel Puig                                          9
# 3                    Brad Miller                                          6
# 4                 Dustin Pedroia                                          4
# ...                          ...                                        ...
# 2424                Jordy Mercer                                          4
# 2425               Jorge Polanco                                          6
# 2426            Jurickson Profar                                          7
# 2427                 Aaron Judge                                          9
# 2428                  Tommy Pham                                          7
#
#      Visiting Team Player 3 ID Visiting Team Player 3 Name  \
# 0                     ramih003              Hanley Ramirez
# 1                     ramih003              Hanley Ramirez
# 2                     ramih003              Hanley Ramirez
# 3                     canor001               Robinson Cano
# 4                     ortid001                 David Ortiz
# ...                        ...                         ...
# 2424                  cabrm001              Miguel Cabrera
# 2425                  sanom001                 Miguel Sano
# 2426                  piscs001            Stephen Piscotty
# 2427                  gardb001               Brett Gardner
# 2428                  choij001                 Ji-Man Choi
#
#       Visiting Team Player 3 Defensive Position Visiting Team Player 4 ID  \
# 0                                             6                  gonza003
# 1                                             6                  gonza003
# 2                                             6                  gonza003
# 3                                             4                  smoaj001
# 4                                            10                  napom001
# ...                                         ...                       ...
# 2424                                         10                  hickj001
# 2425                                         10                  cronc002
# 2426                                          9                  davik003
# 2427                                          8                  stanm004
# 2428                                          3                  garca003
#
#      Visiting Team Player 4 Name  Visiting Team Player 4 Defensive Position  \
# 0                Adrian Gonzalez                                          3
# 1                Adrian Gonzalez                                          3
# 2                Adrian Gonzalez                                          3
# 3                   Justin Smoak                                          3
# 4                    Mike Napoli                                          3
# ...                          ...                                        ...
# 2424                  John Hicks                                          3
# 2425                   C.J. Cron                                          3
# 2426                 Khris Davis                                         10
# 2427           Giancarlo Stanton                                         10
# 2428              Avisail Garcia                                          9
#
#      Visiting Team Player 5 ID Visiting Team Player 5 Name  \
# 0                     vanss001             Scott Van Slyke
# 1                     ethia001                Andre Ethier
# 2                     ethia001                Andre Ethier
# 3                     morrl001              Logan Morrison
# 4                     carpm001                   Mike Carp
# ...                        ...                         ...
# 2424                  rodrr009             Ronny Rodriguez
# 2425                  cavej001                   Jake Cave
# 2426                  brows003                  Seth Brown
# 2427                  torrg001              Gleyber Torres
# 2428                  kierk001             Kevin Kiermaier
#
#       Visiting Team Player 5 Defensive Position Visiting Team Player 6 ID  \
# 0                                             7                  uribj002
# 1                                             8                  ellia001
# 2                                             8                  uribj002
# 3                                            10                  seagk001
# 4                                             7                  sizeg001
# ...                                         ...                       ...
# 2424                                          5                  stewc002
# 2425                                          8                  schoj001
# 2426                                          3                  phegj001
# 2427                                          4                  sancg002
# 2428                                          8                  robed004
#
#      Visiting Team Player 6 Name  Visiting Team Player 6 Defensive Position  \
# 0                     Juan Uribe                                          5
# 1                     A.J. Ellis                                          2
# 2                     Juan Uribe                                          5
# 3                    Kyle Seager                                          5
# 4                 Grady Sizemore                                          8
# ...                          ...                                        ...
# 2424            Christin Stewart                                          7
# 2425             Jonathan Schoop                                          4
# 2426                Josh Phegley                                          2
# 2427                Gary Sanchez                                          2
# 2428            Daniel Robertson                                          4
#
#      Visiting Team Player 7 ID Visiting Team Player 7 Name  \
# 0                     ethia001                Andre Ethier
# 1                     baxtm001                 Mike Baxter
# 2                     ellia001                  A.J. Ellis
# 3                     saunm001            Michael Saunders
# 4                     bogax001             Xander Bogaerts
# ...                        ...                         ...
# 2424                  demet001            Travis Demeritte
# 2425                  castj006                Jason Castro
# 2426                  neuss001               Sheldon Neuse
# 2427                  gregd001              Didi Gregorius
# 2428                  duffm002                  Matt Duffy
#
#       Visiting Team Player 7 Defensive Position Visiting Team Player 8 ID  \
# 0                                             8                  ellia001
# 1                                             7                  uribj002
# 2                                             2                  gordd002
# 3                                             9                  ackld001
# 4                                             6                  piera001
# ...                                         ...                       ...
# 2424                                          9                  greig001
# 2425                                          2                  torrr001
# 2426                                          5                  barrf001
# 2427                                          6                  urshg001
# 2428                                          5                  zunim001
#
#      Visiting Team Player 8 Name  Visiting Team Player 8 Defensive Position  \
# 0                     A.J. Ellis                                          2
# 1                     Juan Uribe                                          5
# 2                     Dee Gordon                                          4
# 3                  Dustin Ackley                                          7
# 4                A.J. Pierzynski                                          2
# ...                          ...                                        ...
# 2424             Grayson Greiner                                          2
# 2425             Ronald Torreyes                                          5
# 2426            Franklin Barreto                                          4
# 2427            Giovanny Urshela                                          5
# 2428                 Mike Zunino                                          2
#
#      Visiting Team Player 9 ID Visiting Team Player 9 Name  \
# 0                     kersc001             Clayton Kershaw
# 1                     ryu-h001                Hyun-Jin Ryu
# 2                     ryu-h001                Hyun-Jin Ryu
# 3                     zunim001                 Mike Zunino
# 4                     middw001           Will Middlebrooks
# ...                        ...                         ...
# 2424                  castw003                Willi Castro
# 2425                  milli001                  Ian Miller
# 2426                  bolts001                   Skye Bolt
# 2427                  maybc001              Cameron Maybin
# 2428                  adamw002                Willy Adames
#
#       Visiting Team Player 9 Defensive Position Home Team Player 1 ID  \
# 0                                             1              polla001
# 1                                             1              polla001
# 2                                             1              cabre001
# 3                                             2              calhk001
# 4                                             5              markn001
# ...                                         ...                   ...
# 2424                                          6              sancc001
# 2425                                          9              merrw001
# 2426                                          8              longs001
# 2427                                          7              choos001
# 2428                                          6              hernt002
#
#      Home Team Player 1 Name  Home Team Player 1 Defensive Position  \
# 0               A.J. Pollock                                      8
# 1               A.J. Pollock                                      8
# 2             Everth Cabrera                                      6
# 3               Kole Calhoun                                      9
# 4              Nick Markakis                                      9
# ...                      ...                                    ...
# 2424          Yolmer Sanchez                                      4
# 2425         Whit Merrifield                                      4
# 2426               Shed Long                                      7
# 2427           Shin-Soo Choo                                     10
# 2428       Teoscar Hernandez                                      7
#
#      Home Team Player 2 ID Home Team Player 2 Name  \
# 0                 hilla001              Aaron Hill
# 1                 hilla001              Aaron Hill
# 2                 denoc001          Chris Denorfia
# 3                 troum001              Mike Trout
# 4                 hardj003              J.J. Hardy
# ...                    ...                     ...
# 2424              andet001            Tim Anderson
# 2425              solej001             Jorge Soler
# 2426              crawj002           J.P. Crawford
# 2427              andre001            Elvis Andrus
# 2428              biggc002            Cavan Biggio
#
#       Home Team Player 2 Defensive Position Home Team Player 3 ID  \
# 0                                         4              goldp001
# 1                                         4              goldp001
# 2                                         9              headc001
# 3                                         8              pujoa001
# 4                                         6              jonea003
# ...                                     ...                   ...
# 2424                                      6              abrej003
# 2425                                     10              dozih001
# 2426                                      6              nolaa002
# 2427                                      6              calhw001
# 2428                                      4              gricr001
#
#      Home Team Player 3 Name  Home Team Player 3 Defensive Position  \
# 0           Paul Goldschmidt                                      3
# 1           Paul Goldschmidt                                      3
# 2              Chase Headley                                      5
# 3              Albert Pujols                                      3
# 4                 Adam Jones                                      8
# ...                      ...                                    ...
# 2424              Jose Abreu                                      3
# 2425           Hunter Dozier                                      5
# 2426             Austin Nola                                      3
# 2427          Willie Calhoun                                      7
# 2428          Randal Grichuk                                      9
#
#      Home Team Player 4 ID Home Team Player 4 Name  \
# 0                 pradm001            Martin Prado
# 1                 pradm001            Martin Prado
# 2                 gyorj001             Jedd Gyorko
# 3                 hamij003           Josh Hamilton
# 4                 davic003             Chris Davis
# ...                    ...                     ...
# 2424              moncy001            Yoan Moncada
# 2425              gorda001             Alex Gordon
# 2426              seagk001             Kyle Seager
# 2427              santd001           Danny Santana
# 2428              tellr001            Rowdy Tellez
#
#       Home Team Player 4 Defensive Position Home Team Player 5 ID  \
# 0                                         5              trumm001
# 1                                         5              montm001
# 2                                         4              alony001
# 3                                         7              freed001
# 4                                         3              cruzn002
# ...                                     ...                   ...
# 2424                                      5              jimee001
# 2425                                      7              mcbrr001
# 2426                                      5              lewik001
# 2427                                      9              odorr001
# 2428                                     10              smoaj001
#
#      Home Team Player 5 Name  Home Team Player 5 Defensive Position  \
# 0                Mark Trumbo                                      7
# 1             Miguel Montero                                      2
# 2              Yonder Alonso                                      3
# 3               David Freese                                      5
# 4                Nelson Cruz                                      7
# ...                      ...                                    ...
# 2424            Eloy Jimenez                                      7
# 2425            Ryan McBroom                                      9
# 2426              Kyle Lewis                                      9
# 2427            Rougned Odor                                      4
# 2428            Justin Smoak                                      3
#
#      Home Team Player 6 ID Home Team Player 6 Name  \
# 0                 montm001          Miguel Montero
# 1                 trumm001             Mark Trumbo
# 2                 medit001            Tommy Medica
# 3                 ibanr001             Raul Ibanez
# 4                 wietm001            Matt Wieters
# ...                    ...                     ...
# 2424              collz001            Zack Collins
# 2425              cuthc001        Cheslor Cuthbert
# 2426              narvo001            Omar Narvaez
# 2427              solan001              Nick Solak
# 2428              valeb001          Breyvic Valera
#
#       Home Team Player 6 Defensive Position Home Team Player 7 ID  \
# 0                                         2              owinc001
# 1                                         7              parrg001
# 2                                         7              venaw001
# 3                                        10              kendh001
# 4                                         2              yound003
# ...                                     ...                   ...
# 2424                                      2              castw002
# 2425                                      3              mejie001
# 2426                                      2              voged001
# 2427                                      5              guzmr001
# 2428                                      5              urenr001
#
#      Home Team Player 7 Name  Home Team Player 7 Defensive Position  \
# 0               Chris Owings                                      6
# 1              Gerardo Parra                                      9
# 2               Will Venable                                      8
# 3             Howie Kendrick                                      4
# 4               Delmon Young                                     10
# ...                      ...                                    ...
# 2424      Welington Castillo                                     10
# 2425             Erick Mejia                                      8
# 2426        Daniel Vogelbach                                     10
# 2427           Ronald Guzman                                      3
# 2428           Richard Urena                                      6
#
#      Home Team Player 8 ID Home Team Player 8 Name  \
# 0                 parrg001           Gerardo Parra
# 1                 gregd001          Didi Gregorius
# 2                 river003             Rene Rivera
# 3                 iannc001          Chris Iannetta
# 4                 flahr001           Ryan Flaherty
# ...                    ...                     ...
# 2424              palkd001            Daniel Palka
# 2425              arteh001        Humberto Arteaga
# 2426              smitm007            Mallex Smith
# 2427              deshd002        Delino DeShields
# 2428              davij007          Jonathan Davis
#
#       Home Team Player 8 Defensive Position Home Team Player 9 ID  \
# 0                                         9              milew001
# 1                                         6              cahit001
# 2                                         2              casha001
# 3                                         2              aybae001
# 4                                         5              schoj001
# ...                                     ...                   ...
# 2424                                      9              engea001
# 2425                                      6              dinin001
# 2426                                      8              gordd002
# 2427                                      8              trevj001
# 2428                                      8              maill001
#
#      Home Team Player 9 Name  Home Team Player 9 Defensive Position  \
# 0                 Wade Miley                                      1
# 1              Trevor Cahill                                      1
# 2             Andrew Cashner                                      1
# 3                Erick Aybar                                      6
# 4            Jonathan Schoop                                      4
# ...                      ...                                    ...
# 2424              Adam Engel                                      8
# 2425               Nick Dini                                      2
# 2426              Dee Gordon                                      4
# 2427            Jose Trevino                                      2
# 2428              Luke Maile                                      2
#
#      Miscellaneous Acquisition Information
# 0              NaN                       Y
# 1              NaN                       Y
# 2              NaN                       Y
# 3              NaN                       Y
# 4              NaN                       Y
# ...            ...                     ...
# 2424           NaN                       Y
# 2425           NaN                       Y
# 2426           NaN                       Y
# 2427           NaN                       Y
# 2428           NaN                       Y
#
# [14577 rows x 161 columns]

# %%
PATH_TO_TEAM_GAMES = './datasets/team_stats/'
def get_team_games(teams_games_dir=PATH_TO_TEAM_GAMES):
    
    def generate_date(date_of_game):
        """Helper function that parses a game id for the date"""
        
        date_of_game = str(date_of_game)
        
        # Parse the date
        year = int(date_of_game[0:4])
        month = int(date_of_game[4:6])
        day = int(date_of_game[6:8])
        
        return date(year, month, day)
    
    team_stats = dict()
    
    for file in os.listdir(teams_games_dir):
        df = pd.read_csv(os.path.join(teams_games_dir, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Date']), axis=1)
        df.rename(columns={'Earned Runs': 'Team Earned Runs'}, inplace=True)
        team_stats[file[0:3]] = df.sort_values(by=['Date', 'Number of game']).reset_index(drop=True)

    return team_stats

# %%
def get_team_rolling_sums(team_games, window=5):
    
    for _, df in team_games.items():
        for col in df.columns[6::]:
            df[f'{col} {window} Game Window'] = df[col].rolling(window).sum()
            df[f'{col} {window} Game Window'] = df[f'{col} {window} Game Window'].shift(1)
        
        df.drop(columns=df.columns[3:33], inplace=True)
        
        # Add BA
        df[f'BA {window} Game Window'] = (df[f'Hits {window} Game Window'] /
                                          df[f'At-bats {window} Game Window'])
        
        # Add SLG = (1B + 2Bx2 + 3Bx3 + HRx4)/AB.
        df[f'SLG {window} Game Window'] = ((df[f'Hits {window} Game Window'] +
                                            df[f'Doubles {window} Game Window'] +
                                            2 * df[f'Triples {window} Game Window'] +
                                            3 * df[f'Homeruns {window} Game Window']) /
                                           df[f'At-bats {window} Game Window'])
        
        # Add OBP = (Hits + Walks + Hit by Pitch) / (At Bats + Walks + Hit by Pitch + Sacrifice Flies
        df[f'OBP {window} Game Window'] = ((df[f'Hits {window} Game Window'] +
                                            df[f'Walks {window} Game Window'] +
                                            df[f'Hit-by-pitch {window} Game Window']) /
                                           (df[f'At-bats {window} Game Window'] + 
                                            df[f'Walks {window} Game Window'] +
                                            df[f'Hit-by-pitch {window} Game Window'] +
                                            df[f'Sacrifice Flies {window} Game Window']))
        
        # OPS = OBS + SLG
        df[f'OPS {window} Game Window'] = (df[f'OBP {window} Game Window'] +
                                           df[f'SLG {window} Game Window'])
        
        # ISO = SLG - BA
        df[f'ISO {window} Game Window'] = (df[f'SLG {window} Game Window'] -
                                           df[f'BA {window} Game Window'])
        
        # Drop stats that won't be needed
        df.drop(columns=(list(df.columns[5:8]) +
                         list(df.columns[9:21]) +
                         list(df.columns[22:30])),
                inplace=True)
        
        df.dropna(inplace=True)
        df.reset_index(drop=True, inplace=True)
            
    return team_games

# %%
get_team_rolling_sums(get_team_games())['NYA']
# Out:
#            Date  Number of game Team  At-bats 5 Game Window  \
# 0    2014-04-06               0  NYA                  169.0
# 1    2014-04-07               0  NYA                  172.0
# 2    2014-04-08               0  NYA                  169.0
# 3    2014-04-09               0  NYA                  177.0
# 4    2014-04-10               0  NYA                  169.0
# ..          ...             ...  ...                    ...
# 962  2019-09-24               0  NYA                  161.0
# 963  2019-09-25               0  NYA                  171.0
# 964  2019-09-27               0  NYA                  166.0
# 965  2019-09-28               0  NYA                  176.0
# 966  2019-09-29               0  NYA                  172.0
#
#      Hits 5 Game Window  RBIs 5 Game Window  Team Earned Runs 5 Game Window  \
# 0                  43.0                13.0                            17.0
# 1                  46.0                17.0                            15.0
# 2                  47.0                20.0                            14.0
# 3                  53.0                21.0                            26.0
# 4                  47.0                18.0                            29.0
# ..                  ...                 ...                             ...
# 962                38.0                29.0                            11.0
# 963                39.0                28.0                            11.0
# 964                32.0                19.0                            14.0
# 965                44.0                30.0                            16.0
# 966                40.0                27.0                            24.0
#
#      BA 5 Game Window  SLG 5 Game Window  OBP 5 Game Window  \
# 0            0.254438           0.319527           0.335079
# 1            0.267442           0.354651           0.345361
# 2            0.278107           0.366864           0.365979
# 3            0.299435           0.435028           0.376884
# 4            0.278107           0.437870           0.352632
# ..                ...                ...                ...
# 962          0.236025           0.503106           0.295455
# 963          0.228070           0.473684           0.284946
# 964          0.192771           0.367470           0.258242
# 965          0.250000           0.494318           0.317949
# 966          0.232558           0.453488           0.298429
#
#      OPS 5 Game Window  ISO 5 Game Window
# 0             0.654605           0.065089
# 1             0.700012           0.087209
# 2             0.732843           0.088757
# 3             0.811913           0.135593
# 4             0.790501           0.159763
# ..                 ...                ...
# 962           0.798560           0.267081
# 963           0.758630           0.245614
# 964           0.625712           0.174699
# 965           0.812267           0.244318
# 966           0.751918           0.220930
#
# [967 rows x 12 columns]

# %% [markdown]
# Now we need to add the pitcher data

# %%
PATH_TO_PITCHER_STATS = './datasets/pitcher_stats/'

def get_pitching_stats(directory=PATH_TO_PITCHER_STATS):
    """Function returns a dictionary, where each key is a player_id
    and each value is a dataframe object containing the player's stats"""
    
    def generate_date(game_id):
        """Helper function that parses a game id for the date"""
        
        # Parse the game_id
        year = int(game_id[3:7])
        month = int(game_id[7:9])
        day = int(game_id[9:11])
        
        return date(year, month, day)
    
    def generate_game_number(game_id):
        """Helper function that parses a game id and returns the game number"""
        return int(game_id[-1])        
    
    player_stats_dict = dict()
    
    for file in tqdm(os.listdir(directory), unit='players', desc='Fetching Pitcher Stats'):
        df = pd.read_csv(os.path.join(directory, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Game ID']), axis=1) 
        df['Game Number'] = df.apply(lambda row : generate_game_number(row['Game ID']), axis=1)
        df['ID'] = file[0:-4]
        df.drop(columns=['Unnamed: 0'], inplace=True)
        player_id = df.iloc[0]['ID']
        player_stats_dict[player_id] = df.sort_values(by=['Date', 'Game Number']).reset_index(drop=True)
    
    return player_stats_dict

# %%
get_pitching_stats()['kersc001']
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=746.0), HTML(value='')))
#           Game ID        ID  Balls  Strikes  Homeruns Allowed  Hits Allowed  \
# 0    ARI201403220  kersc001     28       40                 0             5
# 1    WAS201405060  kersc001     21       36                 0             9
# 2    LAN201405110  kersc001     26       30                 1             7
# 3    ARI201405170  kersc001     20       16                 0             6
# 4    PHI201405230  kersc001     30       39                 0             2
# ..            ...       ...    ...      ...               ...           ...
# 157  ARI201908310  kersc001     32       33                 2             5
# 158  LAN201909060  kersc001     30       33                 1             7
# 159  NYN201909130  kersc001     40       32                 1             4
# 160  LAN201909200  kersc001     32       37                 3             8
# 161  SDN201909260  kersc001     23       31                 0             2
#
#      Strikeouts  Pickoff Errors  Pickoffs  Wild Pitches  Balks  Walks  \
# 0             7               0         0             1      0      1
# 1             9               0         1             0      0      0
# 2             9               0         0             0      0      0
# 3             3               0         0             0      1      2
# 4             9               0         0             0      0      3
# ..          ...             ...       ...           ...    ...    ...
# 157           6               0         0             0      0      2
# 158           6               0         0             0      0      3
# 159           5               0         0             0      0      3
# 160           5               0         0             0      0      1
# 161           7               0         0             1      0      1
#
#      Intentional Walks  Hit by Pitch  Earned Runs  Innings Pitched  \
# 0                    0             0            1         6.666667
# 1                    0             0            0         7.000000
# 2                    0             0            3         7.000000
# 3                    0             0            6         1.666667
# 4                    0             0            0         6.000000
# ..                 ...           ...          ...              ...
# 157                  0             0            5         5.000000
# 158                  0             0            1         4.000000
# 159                  0             0            1         6.333333
# 160                  0             0            4         6.000000
# 161                  0             0            0         6.000000
#
#            Date  Game Number
# 0    2014-03-22            0
# 1    2014-05-06            0
# 2    2014-05-11            0
# 3    2014-05-17            0
# 4    2014-05-23            0
# ..          ...          ...
# 157  2019-08-31            0
# 158  2019-09-06            0
# 159  2019-09-13            0
# 160  2019-09-20            0
# 161  2019-09-26            0
#
# [162 rows x 18 columns]

# %%
def get_pitching_rolling_sums(dictionary, window=10):
    """Function that will generate statsistics based on a rolling window"""
    
    for k, df in tqdm(dictionary.items(), unit='players', desc='Generating Rolling Pitcher Stats'):
        df = df.copy()
        
        for col in df.columns:
            if col in {'Game ID', 'ID', 'Date', 'Game Number'}:
                continue

            df[f'{col} {window} Game Window'] = df[col].rolling(window).sum()
            df[f'{col} {window} Game Window'] = df[f'{col} {window} Game Window'].shift(1)
        
        # Calculate ERA
        df[f'ERA {window} Game Window'] = ((df[f'Earned Runs {window} Game Window'] * 9) /
                                           df[f'Innings Pitched {window} Game Window'])
        
        # Calculate WHIP
        # (Walks + hits) / innings pitched
        df[f'WHIP {window} Game Window'] = ((df[f'Hits Allowed {window} Game Window'] +
                                             df[f'Walks {window} Game Window']) /
                                            (df[f'Innings Pitched {window} Game Window']))
        
        # Calculate FIP
        # (13 * HR + 3*(BB + HBP) - 2*K) / IP + constant
        df[f'FIP {window} Game Window'] = (((13 * df[f'Homeruns Allowed {window} Game Window']) +
                                             (3 * (df[f'Walks {window} Game Window'] +
                                                   df[f'Hit by Pitch {window} Game Window'])) -
                                             (2 * df[f'Strikeouts {window} Game Window'])) /
                                            (df[f'Innings Pitched {window} Game Window'])) + 3.2

        df = df.filter(items=['Game ID',
                              'ID',
                              'Date',
                              'Game Number',
                              f'Homeruns Allowed {window} Game Window',
                              f'Hits Allowed {window} Game Window',
                              f'Strikeouts {window} Game Window',
                              f'Walks {window} Game Window',
                              f'Earned Runs {window} Game Window',
                              f'ERA {window} Game Window',
                              f'WHIP {window} Game Window',
                              f'FIP {window} Game Window'])
    
        df.dropna(inplace=True)
        
        dictionary[k] = df
    
    return dictionary

# %%
get_pitching_rolling_sums(get_pitching_stats(), window=5)['kersc001']
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=746.0), HTML(value='')))
# HBox(children=(HTML(value='Generating Rolling Pitcher Stats'), FloatProgress(value=0.0, max=746.0), HTML(value…
#           Game ID        ID        Date  Game Number  \
# 5    LAN201405280  kersc001  2014-05-28            0
# 6    LAN201406020  kersc001  2014-06-02            0
# 7    COL201406080  kersc001  2014-06-08            0
# 8    LAN201406130  kersc001  2014-06-13            0
# 9    LAN201406180  kersc001  2014-06-18            0
# ..            ...       ...         ...          ...
# 157  ARI201908310  kersc001  2019-08-31            0
# 158  LAN201909060  kersc001  2019-09-06            0
# 159  NYN201909130  kersc001  2019-09-13            0
# 160  LAN201909200  kersc001  2019-09-20            0
# 161  SDN201909260  kersc001  2019-09-26            0
#
#      Homeruns Allowed 5 Game Window  Hits Allowed 5 Game Window  \
# 5                               1.0                        29.0
# 6                               2.0                        31.0
# 7                               3.0                        26.0
# 8                               3.0                        22.0
# 9                               3.0                        24.0
# ..                              ...                         ...
# 157                             7.0                        22.0
# 158                             8.0                        21.0
# 159                             9.0                        24.0
# 160                            10.0                        26.0
# 161                            10.0                        28.0
#
#      Strikeouts 5 Game Window  Walks 5 Game Window  Earned Runs 5 Game Window  \
# 5                        37.0                  6.0                       10.0
# 6                        39.0                  6.0                       12.0
# 7                        39.0                  6.0                       14.0
# 8                        39.0                  6.0                       12.0
# 9                        43.0                  5.0                        7.0
# ..                        ...                  ...                        ...
# 157                      42.0                  9.0                        9.0
# 158                      43.0                  6.0                       12.0
# 159                      40.0                  8.0                       12.0
# 160                      35.0                 11.0                       13.0
# 161                      34.0                  9.0                       14.0
#
#      ERA 5 Game Window  WHIP 5 Game Window  FIP 5 Game Window
# 5             3.176471            1.235294           1.682353
# 6             3.767442            1.290698           2.013953
# 7             4.247191            1.078652           2.492135
# 8             3.903614            1.012048           2.440964
# 9             1.909091            0.878788           2.230303
# ..                 ...                 ...                ...
# 157           2.454545            0.939394           4.321212
# 158           3.375000            0.843750           4.418750
# 159           3.724138            1.103448           5.406897
# 160           4.129412            1.305882           6.588235
# 161           4.447059            1.305882           6.447059
#
# [157 rows x 12 columns]

# %%
columns = ['Date',
           'Number of game',
           'Visiting Team',
           'Visiting Team Game Number',
           'Home Team',
           'Home Team Game Number',
           'Visiting Team Score',
           'Home Team Score',
           'Visiting Team Starting Pitcher ID',
           'Home Team Starting Pitcher ID']

filtered_game_logs = game_logs.filter(items=columns)
filtered_game_logs
# Out:
#             Date  Number of game Visiting Team  Visiting Team Game Number  \
# 0     2014-03-22               0           LAN                          1
# 1     2014-03-23               0           LAN                          2
# 2     2014-03-30               0           LAN                          3
# 3     2014-03-31               0           SEA                          1
# 4     2014-03-31               0           BOS                          1
# ...          ...             ...           ...                        ...
# 2424  2019-09-29               0           DET                        161
# 2425  2019-09-29               0           MIN                        162
# 2426  2019-09-29               0           OAK                        162
# 2427  2019-09-29               0           NYA                        162
# 2428  2019-09-29               0           TBA                        162
#
#      Home Team  Home Team Game Number  Visiting Team Score  Home Team Score  \
# 0          ARI                      1                    3                1
# 1          ARI                      2                    7                5
# 2          SDN                      1                    1                3
# 3          ANA                      1                   10                3
# 4          BAL                      1                    1                2
# ...        ...                    ...                  ...              ...
# 2424       CHA                    161                    3                5
# 2425       KCA                    162                    4                5
# 2426       SEA                    162                    1                3
# 2427       TEX                    162                    1                6
# 2428       TOR                    162                    3                8
#
#      Visiting Team Starting Pitcher ID Home Team Starting Pitcher ID
# 0                             kersc001                      milew001
# 1                             ryu-h001                      cahit001
# 2                             ryu-h001                      casha001
# 3                             hernf002                      weavj003
# 4                             lestj001                      tillc001
# ...                                ...                           ...
# 2424                          turns003                      detwr001
# 2425                          perem004                      lopej004
# 2426                          roart001                      dunnj002
# 2427                          greec003                      lynnl001
# 2428                          snelb001                      buchc001
#
# [14577 rows x 10 columns]

# %%
def generate_training_data(schedule, team_data, pitching_data):
    
    # Get the batting and pitching stats
    batting = pd.concat([v for k,v in team_data.items()])
    pitching = pd.concat([v for k,v in pitching_data.items()])
    
    # Merge home batting with schedule
    home_batting = pd.merge(schedule,
                            batting,
                            how='left',
                            left_on=['Date', 'Number of game', 'Home Team'],
                            right_on=['Date', 'Number of game', 'Team']).drop(columns=['Team'])
    
    # Merge away batting with schedule
    away_batting = pd.merge(schedule,
                            batting,
                            how='left',
                            left_on=['Date', 'Number of game', 'Visiting Team'],
                            right_on=['Date', 'Number of game', 'Team']).drop(columns=['Team'])
    
    # Merge home pitching with schedule
    home_pitching = pd.merge(schedule,
                             pitching,
                             how='left',
                             left_on=['Date', 'Number of game', 'Home Team Starting Pitcher ID'],
                             right_on=['Date', 'Game Number', 'ID']).drop(columns=['Game Number', 'Game ID', 'ID'])
    
    # Merge away pitching with schedule
    away_pitching = pd.merge(schedule,
                             pitching,
                             how='left',
                             left_on=['Date', 'Number of game', 'Visiting Team Starting Pitcher ID'],
                             right_on=['Date', 'Game Number', 'ID']).drop(columns=['Game Number', 'Game ID', 'ID'])
    
    # Merge home batting with home pitching
    df_home = pd.merge(home_batting,
                       home_pitching,
                       how='left',
                       on=list(schedule.columns))
    
    # Merge away batting with away pitching
    df_away = pd.merge(away_batting,
                       away_pitching,
                       how='left',
                       on=list(schedule.columns))
    
    # Merge home and away
    home_and_away = pd.merge(df_home,
                             df_away,
                             how='left',
                             on=list(schedule.columns))
        
    # Create differences between home and away
    for i, home_col in enumerate(home_and_away.columns[len(schedule.columns):len(df_home.columns)]):
        suffix_index = home_col.find('_')
        col_name = 'Difference ' + home_col[:suffix_index]
        away_col = home_col[:-2] + '_y'
        home_and_away[col_name] = home_and_away[home_col] - home_and_away[away_col]
    
    return home_and_away.drop(columns=list(home_and_away.columns)[len(schedule.columns):
                                                                  2*len(df_home.columns)-len(schedule.columns)]).dropna()

# %% [markdown]
# # Training a Random Forrest Classifier

# %%
data = generate_training_data(filtered_game_logs,
                              get_team_rolling_sums(get_team_games(), window=5),
                              get_pitching_rolling_sums(get_pitching_stats(), window=5))

training_data = data.dropna().reset_index(drop=True)
training_data['Winner'] = np.where(training_data["Home Team Score"] >
                                   training_data["Visiting Team Score"], 1, 0)
training_data.drop(columns=['Date',
                            'Number of game',
                            'Visiting Team',
                            'Visiting Team Game Number',
                            'Home Team',
                            'Home Team Game Number',
                            'Home Team Score',
                            'Visiting Team Score',
                            'Visiting Team Starting Pitcher ID',
                            'Home Team Starting Pitcher ID'],
                   inplace=True)

X_train, X_test, y_train, y_test = train_test_split(training_data.drop(columns=['Winner']),
                                                    training_data.filter(items=['Winner']).pop('Winner'),
                                                    random_state=42)
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=746.0), HTML(value='')))
# HBox(children=(HTML(value='Generating Rolling Pitcher Stats'), FloatProgress(value=0.0, max=746.0), HTML(value…

# %%
# Number of trees in random forest
n_estimators = [i for i in range(100, 1100, 100)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [i for i in range(1, 21)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_param_grid = {'n_estimators': n_estimators,
                      'max_features': max_features,
                      'max_depth': max_depth,
                      'min_samples_split': min_samples_split,
                      'min_samples_leaf': min_samples_leaf,
                      'bootstrap': bootstrap}
# Use the random grid to find the best hyperparameters
# First create the base model to tune
rf = RandomForestClassifier()

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf,
                               param_distributions = random_param_grid,
                               n_iter = 50,
                               cv = 3,
                               verbose = 2,
                               random_state = 42,
                               n_jobs = -1)

# Fit the random search model
rf_random.fit(X_train, y_train)

# %%
rf_random.best_params_

# %%
best_params = {'n_estimators': 800,
               'min_samples_split': 2,
               'min_samples_leaf': 4,
               'max_features': 'sqrt',
               'max_depth': 2,
               'bootstrap': False,
               'random_state': 42}

# %%
rf = RandomForestClassifier(**best_params)
rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 0.5633724176437744

# %%
rf.score(X_test, y_test)
# Out:
# 0.5457286432160804

# %%
rf.predict_proba(X_train)
# Out:
# array([[0.44063418, 0.55936582],
#        [0.44002376, 0.55997624],
#        [0.52121273, 0.47878727],
#        ...,
#        [0.52580111, 0.47419889],
#        [0.46422273, 0.53577727],
#        [0.47810787, 0.52189213]])

# %% [markdown]
# # Gaussian Bayes Naive Bayes Model

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
gnb.score(X_train, y_train)
# Out:
# 0.5490787269681742

# %%
gnb.score(X_test, y_test)
# Out:
# 0.5366834170854271
