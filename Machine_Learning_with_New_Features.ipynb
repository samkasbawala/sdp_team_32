# %% [markdown]
# # Imports

# %%
import os
import shutil
import pickle
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from datetime import date
from functools import reduce
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tqdm.notebook import tqdm

pd.set_option('display.max_columns', None)

PATH_TO_GAME_LOGS = './datasets/retro_sheet_gls/'
PATH_TO_TEAM_GAMES = './datasets/team_stats/'
TEAM_ROLLING_SUMS_DIR = './datasets/team_rolling_14/'
PATH_TO_PITCHER_STATS = './datasets/pitcher_stats/'
PITCHING_ROLLING_SUMS_DIR = './datasets/pitching_rolling_10/'
MODEL_SAVE_DIR = './datasets/models/'
DATA_2020 = './datasets/data_2020/'
LATEST_TEAM_DIR = os.path.join(DATA_2020, 'teams')
LATEST_PITCHER_DIR = os.path.join(DATA_2020, 'pitchers')

# %% [markdown]
# # Utils

# %%
def clean_dir(path):
    """Makes a clean directory, removes all files and folders in the specified path"""
    
    if not os.path.exists(path):
        os.mkdir(path)
    
    for filename in os.listdir(path):
        file_path = os.path.join(path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"Failed to delete {file_path}. Reason: {e}")

# %% [markdown]
# # Data

# %%
def get_game_logs(game_log_dir=PATH_TO_GAME_LOGS):
    """Function to get game log"""
    
    def generate_date(date_of_game):
        """Helper function that parses a game id for the date"""
        
        date_of_game = str(date_of_game)
        
        # Parse the date
        year = int(date_of_game[0:4])
        month = int(date_of_game[4:6])
        day = int(date_of_game[6:8])
        
        return date(year, month, day)
    
    dfs = []
    for file in os.listdir(game_log_dir):
        df = pd.read_csv(os.path.join(game_log_dir, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Date']), axis=1)
        dfs.append(df)
    return pd.concat(dfs)

# %%
game_logs = get_game_logs()
game_logs
# Out:
#            Date  Number of game  Day Visiting Team Visiting Team League  \
# 0    2014-03-22               0  Sat           LAN                   NL
# 1    2014-03-23               0  Sun           LAN                   NL
# 2    2014-03-30               0  Sun           LAN                   NL
# 3    2014-03-31               0  Mon           SEA                   AL
# 4    2014-03-31               0  Mon           BOS                   AL
# ..          ...             ...  ...           ...                  ...
# 893  2020-09-27               0  Sun           MIA                   NL
# 894  2020-09-27               0  Sun           SEA                   AL
# 895  2020-09-27               0  Sun           PHI                   NL
# 896  2020-09-27               0  Sun           HOU                   AL
# 897  2020-09-27               0  Sun           BAL                   AL
#
#      Visiting Team Game Number Home Team Home Team League  \
# 0                            1       ARI               NL
# 1                            2       ARI               NL
# 2                            3       SDN               NL
# 3                            1       ANA               AL
# 4                            1       BAL               AL
# ..                         ...       ...              ...
# 893                         60       NYA               AL
# 894                         60       OAK               AL
# 895                         60       TBA               AL
# 896                         60       TEX               AL
# 897                         60       TOR               AL
#
#      Home Team Game Number  Visiting Team Score  Home Team Score  \
# 0                        1                    3                1
# 1                        2                    7                5
# 2                        1                    1                3
# 3                        1                   10                3
# 4                        1                    1                2
# ..                     ...                  ...              ...
# 893                     60                    5                0
# 894                     60                    2                6
# 895                     60                    0                5
# 896                     60                    4                8
# 897                     60                    7                5
#
#      Length of Game (outs) Time of Game (Day/Night) Completion Information  \
# 0                       54                        N                    NaN
# 1                       54                        D                    NaN
# 2                       51                        N                    NaN
# 3                       54                        N                    NaN
# 4                       51                        D                    NaN
# ..                     ...                      ...                    ...
# 893                     54                        D                    NaN
# 894                     51                        D                    NaN
# 895                     51                        D                    NaN
# 896                     51                        D                    NaN
# 897                     54                        D                    NaN
#
#      Forfeit Information Protest Information Park ID  Attendance  \
# 0                    NaN                 NaN   SYD01     38266.0
# 1                    NaN                 NaN   SYD01     38079.0
# 2                    NaN                 NaN   SAN02     45567.0
# 3                    NaN                 NaN   ANA01     44152.0
# 4                    NaN                 NaN   BAL12     46685.0
# ..                   ...                 ...     ...         ...
# 893                  NaN                 NaN   NYC21         NaN
# 894                  NaN                 NaN   OAK01         NaN
# 895                  NaN                 NaN   STP01         NaN
# 896                  NaN                 NaN   ARL02         NaN
# 897                  NaN                 NaN   BUF05         NaN
#
#      Length of Game (minutes) Visiting Team Line Score Home Team Line Score  \
# 0                         169                 10200000            000001000
# 1                         241                102021100            000000014
# 2                         169                    10000            00000003x
# 3                         197                 10001206            201000000
# 4                         173                   100000            01000010x
# ..                        ...                      ...                  ...
# 893                       185                030010010            000000000
# 894                       186                110000000            10001031x
# 895                       179                000000000            01200200x
# 896                       208                101100010            01051010x
# 897                       172                001330000            013000010
#
#      Visiting Team At-bats  Visiting Team Hits  Visiting Team Doubles  \
# 0                       33                   5                      2
# 1                       34                  13                      3
# 2                       31                   4                      0
# 3                       36                  11                      4
# 4                       36                   9                      2
# ..                     ...                 ...                    ...
# 893                     35                   9                      1
# 894                     32                   4                      0
# 895                     32                   6                      1
# 896                     35                   8                      0
# 897                     35                  10                      2
#
#      Visiting Team Triples  Visiting Team Homeruns  Visiting Team RBIs  \
# 0                        0                       1                   3
# 1                        0                       0                   6
# 2                        0                       0                   1
# 3                        2                       1                  10
# 4                        0                       1                   1
# ..                     ...                     ...                 ...
# 893                      0                       2                   5
# 894                      0                       0                   2
# 895                      0                       0                   0
# 896                      0                       3                   4
# 897                      2                       0                   7
#
#      Visiting Team Sacrifice Hits  Visiting Team Sacrifice Flies  \
# 0                               0                              0
# 1                               1                              2
# 2                               0                              0
# 3                               0                              1
# 4                               0                              0
# ..                            ...                            ...
# 893                             0                              0
# 894                             0                              0
# 895                             0                              0
# 896                             0                              0
# 897                             0                              1
#
#      Visiting Team Hit-by-pitch  Visiting Team Walks  \
# 0                             1                    3
# 1                             2                    8
# 2                             0                    3
# 3                             0                    8
# 4                             1                    3
# ..                          ...                  ...
# 893                           1                    4
# 894                           1                    2
# 895                           0                    1
# 896                           0                    5
# 897                           0                    4
#
#      Visiting Team Intentional Walks  Visiting Team Strikeouts  \
# 0                                  0                        11
# 1                                  0                         7
# 2                                  0                         9
# 3                                  1                        11
# 4                                  0                         6
# ..                               ...                       ...
# 893                                0                         7
# 894                                0                        16
# 895                                0                         5
# 896                                0                         7
# 897                                0                         5
#
#      Visiting Team Stolen Bases  Visiting Team Caught Stealing  \
# 0                             0                              0
# 1                             1                              0
# 2                             0                              0
# 3                             1                              1
# 4                             0                              0
# ..                          ...                            ...
# 893                           0                              0
# 894                           1                              1
# 895                           0                              0
# 896                           0                              0
# 897                           0                              1
#
#      Visiting Team Grounded into DP  \
# 0                                 0
# 1                                 1
# 2                                 0
# 3                                 0
# 4                                 0
# ..                              ...
# 893                               1
# 894                               0
# 895                               2
# 896                               0
# 897                               1
#
#      Visiting Team Awarded First Base due to CI  Visiting Team Left on Base  \
# 0                                             0                           7
# 1                                             0                          13
# 2                                             0                           6
# 3                                             0                           8
# 4                                             0                          12
# ..                                          ...                         ...
# 893                                           0                           8
# 894                                           0                           6
# 895                                           0                           6
# 896                                           0                           9
# 897                                           0                           6
#
#      Visiting Team Pitchers Used  Visiting Team Individual Earned Runs  \
# 0                              4                                     1
# 1                              8                                     5
# 2                              4                                     2
# 3                              5                                     2
# 4                              2                                     2
# ..                           ...                                   ...
# 893                            3                                     0
# 894                            5                                     6
# 895                            4                                     5
# 896                            3                                     8
# 897                            6                                     4
#
#      Visiting Team Earned Runs  Visiting Team Wild Pitches  \
# 0                            1                           1
# 1                            5                           0
# 2                            2                           0
# 3                            2                           2
# 4                            2                           0
# ..                         ...                         ...
# 893                          0                           0
# 894                          6                           0
# 895                          5                           1
# 896                          8                           1
# 897                          4                           1
#
#      Visiting Team Balks  Visiting Team Putouts  Visiting Team Assists  \
# 0                      0                     27                     13
# 1                      0                     27                      4
# 2                      0                     24                     12
# 3                      0                     27                      5
# 4                      0                     24                     11
# ..                   ...                    ...                    ...
# 893                    1                     27                     14
# 894                    0                     24                      7
# 895                    0                     24                     11
# 896                    0                     24                      6
# 897                    0                     27                      8
#
#      Visiting Team Errors  Visiting Team Passed Balls  \
# 0                       1                           0
# 1                       1                           0
# 2                       2                           0
# 3                       1                           0
# 4                       0                           0
# ..                    ...                         ...
# 893                     0                           0
# 894                     0                           0
# 895                     0                           0
# 896                     1                           0
# 897                     2                           0
#
#      Visiting Team Double Plays  Visiting Team Triple Plays  \
# 0                             0                           0
# 1                             2                           0
# 2                             2                           0
# 3                             0                           0
# 4                             2                           0
# ..                          ...                         ...
# 893                           2                           0
# 894                           0                           0
# 895                           2                           0
# 896                           2                           0
# 897                           0                           0
#
#      Home Team At-bats  Home Team Hits  Home Team Doubles  Home Team Triples  \
# 0                   33               5                  1                  0
# 1                   35               8                  0                  0
# 2                   27               5                  0                  0
# 3                   34               6                  1                  0
# 4                   28               6                  0                  0
# ..                 ...             ...                ...                ...
# 893                 31               6                  0                  0
# 894                 34              10                  4                  0
# 895                 32               9                  1                  1
# 896                 33              11                  0                  0
# 897                 34               7                  2                  0
#
#      Home Team Homeruns  Home Team RBIs  Home Team Sacrifice Hits  \
# 0                     0               1                         0
# 1                     1               5                         0
# 2                     1               3                         2
# 3                     1               3                         0
# 4                     1               1                         0
# ..                  ...             ...                       ...
# 893                   0               0                         0
# 894                   1               6                         0
# 895                   0               4                         0
# 896                   2               7                         0
# 897                   2               4                         0
#
#      Home Team Sacrifice Flies  Home Team Hit-by-pitch  Home Team Walks  \
# 0                            0                       0                2
# 1                            0                       0                8
# 2                            0                       0                4
# 3                            0                       1                1
# 4                            0                       0                1
# ..                         ...                     ...              ...
# 893                          0                       0                4
# 894                          0                       1                6
# 895                          0                       1                4
# 896                          0                       2                5
# 897                          1                       0                3
#
#      Home Team Intentional Walks  Home Team Strikeouts  \
# 0                              0                    10
# 1                              0                     8
# 2                              0                    10
# 3                              0                    13
# 4                              0                     9
# ..                           ...                   ...
# 893                            0                     4
# 894                            1                     9
# 895                            0                    10
# 896                            0                    11
# 897                            0                     9
#
#      Home Team Stolen Bases  Home Team Caught Stealing  \
# 0                         0                          0
# 1                         0                          0
# 2                         1                          0
# 3                         1                          0
# 4                         0                          0
# ..                      ...                        ...
# 893                       1                          0
# 894                       0                          0
# 895                       0                          0
# 896                       3                          0
# 897                       1                          0
#
#      Home Team Grounded into DP  Home Team Awarded First Base due to CI  \
# 0                             0                                       0
# 1                             2                                       0
# 2                             2                                       0
# 3                             0                                       0
# 4                             2                                       0
# ..                          ...                                     ...
# 893                           2                                       0
# 894                           0                                       0
# 895                           2                                       0
# 896                           1                                       0
# 897                           0                                       0
#
#      Home Team Left on Base  Home Team Pitchers Used  \
# 0                         7                        5
# 1                        11                        6
# 2                         6                        5
# 3                         6                        5
# 4                         3                        5
# ..                      ...                      ...
# 893                       8                        3
# 894                      11                        4
# 895                       8                        4
# 896                       8                        7
# 897                       6                        4
#
#      Home Team Individual Earned Runs  Home Team Earned Runs  \
# 0                                   3                      3
# 1                                   6                      6
# 2                                   1                      1
# 3                                   9                      9
# 4                                   1                      1
# ..                                ...                    ...
# 893                                 5                      5
# 894                                 0                      0
# 895                                 0                      0
# 896                                 4                      4
# 897                                 5                      5
#
#      Home Team Wild Pitches  Home Team Balks  Home Team Putouts  \
# 0                         1                0                 27
# 1                         1                0                 27
# 2                         1                0                 27
# 3                         0                0                 27
# 4                         0                0                 27
# ..                      ...              ...                ...
# 893                       1                0                 27
# 894                       0                0                 27
# 895                       0                0                 27
# 896                       0                0                 27
# 897                       0                0                 27
#
#      Home Team Assists  Home Team Errors  Home Team Passed Balls  \
# 0                   10                 1                       0
# 1                   15                 3                       0
# 2                   10                 0                       0
# 3                    7                 1                       0
# 4                   13                 0                       0
# ..                 ...               ...                     ...
# 893                 13                 0                       0
# 894                  5                 2                       0
# 895                 18                 1                       0
# 896                  7                 0                       0
# 897                  7                 1                       0
#
#      Home Team Double Plays  Home Team Triple Plays Home Plate Umpire ID  \
# 0                         0                       0             welkt901
# 1                         1                       0             scotd901
# 2                         0                       0             culbf901
# 3                         0                       0             westj901
# 4                         0                       0             demud901
# ..                      ...                     ...                  ...
# 893                       1                       0             buckc901
# 894                       0                       0             johna901
# 895                       2                       0             rackd901
# 896                       0                       0             hudsm901
# 897                       1                       0             bacoj901
#
#     Home Plate Umpire Name 1B Umpire ID   1B Umpire Name 2B Umpire ID  \
# 0                Tim Welke     scotd901       Dale Scott     diazl901
# 1               Dale Scott     diazl901         Laz Diaz     carlm901
# 2         Fieldin Culbreth     gonzm901   Manny Gonzalez     reynj901
# 3                 Joe West     fostm901     Marty Foster     drakr901
# 4              Dana DeMuth     kulpr901        Ron Kulpa     hicke901
# ..                     ...          ...              ...          ...
# 893             CB Bucknor     ortir901    Roberto Ortiz     tumpj901
# 894         Adrian Johnson     barrt901      Ted Barrett     rippm901
# 895          David Rackley     barkl901  Lance Barksdale     conrc901
# 896          Marvin Hudson     hamaa901      Adam Hamari     knigb901
# 897             John Bacon     viscj901  Jansen Visconti     nauep901
#
#      2B Umpire Name 3B Umpire ID   3B Umpire Name LF Umpire ID LF Umpire Name  \
# 0          Laz Diaz     carlm901     Mark Carlson          NaN         (none)
# 1      Mark Carlson     welkt901        Tim Welke          NaN         (none)
# 2      Jim Reynolds     barbs901      Sean Barber          NaN         (none)
# 3         Rob Drake     porta901      Alan Porter          NaN         (none)
# 4         Ed Hickox     barrl901    Lance Barrett          NaN         (none)
# ..              ...          ...              ...          ...            ...
# 893    John Tumpane     nelsj901      Jeff Nelson          NaN         (none)
# 894  Mark Ripperger     wolcq901    Quinn Wolcott          NaN         (none)
# 895    Chris Conroy     vanol901    Larry Vanover          NaN         (none)
# 896    Brian Knight     muchm901  Mike Muchlinski          NaN         (none)
# 897     Paul Nauert     fairc901   Chad Fairchild          NaN         (none)
#
#     RF Umpire ID RF Umpire Name Visiting Team Manager ID  \
# 0            NaN         (none)                 mattd001
# 1            NaN         (none)                 mattd001
# 2            NaN         (none)                 mattd001
# 3            NaN         (none)                 mccll001
# 4            NaN         (none)                 farrj001
# ..           ...            ...                      ...
# 893          NaN         (none)                 mattd001
# 894          NaN         (none)                 servs002
# 895          NaN         (none)                 giraj001
# 896          NaN         (none)                 baked002
# 897          NaN         (none)                 hydeb801
#
#     Visiting Team Manager Name Home Team Manager ID Home Team Manager Name  \
# 0                Don Mattingly             gibsk001            Kirk Gibson
# 1                Don Mattingly             gibsk001            Kirk Gibson
# 2                Don Mattingly             blacb001            Buddy Black
# 3              Lloyd McClendon             sciom001          Mike Scioscia
# 4                 John Farrell             showb801         Buck Showalter
# ..                         ...                  ...                    ...
# 893              Don Mattingly             boona001            Aaron Boone
# 894              Scott Servais             melvb001             Bob Melvin
# 895                Joe Girardi             cashk001             Kevin Cash
# 896                Dusty Baker             woodc001         Chris Woodward
# 897               Brandon Hyde             montc001        Charlie Montoyo
#
#     Winning Pitcher ID Winning Pitcher Name Losing Pitcher ID  \
# 0             kersc001      Clayton Kershaw          milew001
# 1             ryu-h001         Hyun-Jin Ryu          cahit001
# 2             thayd001          Dale Thayer          wilsb001
# 3             hernf002      Felix Hernandez          weavj003
# 4             britz001         Zack Britton          lestj001
# ..                 ...                  ...               ...
# 893           castd003       Daniel Castano          schmc002
# 894           petiy001       Yusmeiro Petit          hiray001
# 895           flemj001         Josh Fleming          nolaa001
# 896           benjw001         Wes Benjamin          dejoc001
# 897           lakit001        Travis Lakins          yamas001
#
#     Losing Pitcher Name Saving Pitcher ID Saving Pitcher Name  \
# 0            Wade Miley          jansk001       Kenley Jansen
# 1         Trevor Cahill               NaN              (none)
# 2          Brian Wilson          streh001       Huston Street
# 3          Jered Weaver               NaN              (none)
# 4            Jon Lester          huntt002        Tommy Hunter
# ..                  ...               ...                 ...
# 893      Clarke Schmidt               NaN              (none)
# 894    Yoshihisa Hirano               NaN              (none)
# 895          Aaron Nola               NaN              (none)
# 896       Chase De Jong               NaN              (none)
# 897      Shun Yamaguchi          valdc003        Cesar Valdez
#
#     Game Winning RBI Batter ID Game WInning RBI Batter Name  \
# 0                     ethia001                 Andre Ethier
# 1                     ethia001                 Andre Ethier
# 2                     denoc001               Chris Denorfia
# 3                     almoa001              Abraham Almonte
# 4                     cruzn002                  Nelson Cruz
# ..                         ...                          ...
# 893                   chisj001                Jazz Chisholm
# 894                   lambj001                    Jake Lamb
# 895                   smitk002                  Kevan Smith
# 896                   odorr001                 Rougned Odor
# 897                   ruizr002                     Rio Ruiz
#
#     Visiting Team Starting Pitcher ID Visiting Team Starting Pitcher Name  \
# 0                            kersc001                     Clayton Kershaw
# 1                            ryu-h001                        Hyun-Jin Ryu
# 2                            ryu-h001                        Hyun-Jin Ryu
# 3                            hernf002                     Felix Hernandez
# 4                            lestj001                          Jon Lester
# ..                                ...                                 ...
# 893                          urenj001                          Jose Urena
# 894                          gonzm005                      Marco Gonzales
# 895                          nolaa001                          Aaron Nola
# 896                          dejoc001                       Chase De Jong
# 897                          akink001                         Keegan Akin
#
#     Home Team Starting Pitcher ID Home Team Starting Pitcher Name  \
# 0                        milew001                      Wade Miley
# 1                        cahit001                   Trevor Cahill
# 2                        casha001                  Andrew Cashner
# 3                        weavj003                    Jered Weaver
# 4                        tillc001                   Chris Tillman
# ..                            ...                             ...
# 893                      schmc002                  Clarke Schmidt
# 894                      montf001                  Frankie Montas
# 895                      flemj001                    Josh Fleming
# 896                      lylej001                    Jordan Lyles
# 897                      roart001                    Tanner Roark
#
#     Visiting Team Player 1 ID Visiting Team Player 1 Name  \
# 0                    puigy001                 Yasiel Puig
# 1                    gordd002                  Dee Gordon
# 2                    crawc002               Carl Crawford
# 3                    almoa001             Abraham Almonte
# 4                    navad002                 Daniel Nava
# ..                        ...                         ...
# 893                  dickc002             Corey Dickerson
# 894                  crawj002               J.P. Crawford
# 895                  mccua001            Andrew McCutchen
# 896                  sprig001             George Springer
# 897                  haysa001                 Austin Hays
#
#      Visiting Team Player 1 Defensive Position Visiting Team Player 2 ID  \
# 0                                            9                  turnj001
# 1                                            4                  puigy001
# 2                                            7                  puigy001
# 3                                            8                  millb002
# 4                                            9                  pedrd001
# ..                                         ...                       ...
# 893                                         10                  marts002
# 894                                          6                  lewik001
# 895                                          7                  bohma001
# 896                                          8                  altuj001
# 897                                          7                  stewd002
#
#     Visiting Team Player 2 Name  Visiting Team Player 2 Defensive Position  \
# 0                 Justin Turner                                          4
# 1                   Yasiel Puig                                          9
# 2                   Yasiel Puig                                          9
# 3                   Brad Miller                                          6
# 4                Dustin Pedroia                                          4
# ..                          ...                                        ...
# 893              Starling Marte                                          8
# 894                  Kyle Lewis                                          8
# 895                   Alec Bohm                                          5
# 896                 Jose Altuve                                          4
# 897                  DJ Stewart                                          9
#
#     Visiting Team Player 3 ID Visiting Team Player 3 Name  \
# 0                    ramih003              Hanley Ramirez
# 1                    ramih003              Hanley Ramirez
# 2                    ramih003              Hanley Ramirez
# 3                    canor001               Robinson Cano
# 4                    ortid001                 David Ortiz
# ..                        ...                         ...
# 893                  aguij001               Jesus Aguilar
# 894                  seagk001                 Kyle Seager
# 895                  harpb003                Bryce Harper
# 896                  branm003            Michael Brantley
# 897                  mounr001            Ryan Mountcastle
#
#      Visiting Team Player 3 Defensive Position Visiting Team Player 4 ID  \
# 0                                            6                  gonza003
# 1                                            6                  gonza003
# 2                                            6                  gonza003
# 3                                            4                  smoaj001
# 4                                           10                  napom001
# ..                                         ...                       ...
# 893                                          3                  andeb006
# 894                                          5                  frant002
# 895                                         10                  realj001
# 896                                         10                  brega001
# 897                                          3                  nuner001
#
#     Visiting Team Player 4 Name  Visiting Team Player 4 Defensive Position  \
# 0               Adrian Gonzalez                                          3
# 1               Adrian Gonzalez                                          3
# 2               Adrian Gonzalez                                          3
# 3                  Justin Smoak                                          3
# 4                   Mike Napoli                                          3
# ..                          ...                                        ...
# 893              Brian Anderson                                          5
# 894                   Ty France                                          4
# 895               J.T. Realmuto                                          2
# 896                Alex Bregman                                          5
# 897                Renato Nunez                                         10
#
#     Visiting Team Player 5 ID Visiting Team Player 5 Name  \
# 0                    vanss001             Scott Van Slyke
# 1                    ethia001                Andre Ethier
# 2                    ethia001                Andre Ethier
# 3                    morrl001              Logan Morrison
# 4                    carpm001                   Mike Carp
# ..                        ...                         ...
# 893                  joycm001                  Matt Joyce
# 894                  white005                  Evan White
# 895                  seguj002                 Jean Segura
# 896                  diaza003                Aledmys Diaz
# 897                  ruizr002                    Rio Ruiz
#
#      Visiting Team Player 5 Defensive Position Visiting Team Player 6 ID  \
# 0                                            7                  uribj002
# 1                                            8                  ellia001
# 2                                            8                  uribj002
# 3                                           10                  seagk001
# 4                                            7                  sizeg001
# ..                                         ...                       ...
# 893                                          9                  bertj001
# 894                                          3                  marmj001
# 895                                          4                  gregd001
# 896                                          7                  gurry001
# 897                                          5                  albeh001
#
#     Visiting Team Player 6 Name  Visiting Team Player 6 Defensive Position  \
# 0                    Juan Uribe                                          5
# 1                    A.J. Ellis                                          2
# 2                    Juan Uribe                                          5
# 3                   Kyle Seager                                          5
# 4                Grady Sizemore                                          8
# ..                          ...                                        ...
# 893                   Jon Berti                                          4
# 894             Jose Marmolejos                                         10
# 895              Didi Gregorius                                          6
# 896            Yulieski Gurriel                                          3
# 897              Hanser Alberto                                          4
#
#     Visiting Team Player 7 ID Visiting Team Player 7 Name  \
# 0                    ethia001                Andre Ethier
# 1                    baxtm001                 Mike Baxter
# 2                    ellia001                  A.J. Ellis
# 3                    saunm001            Michael Saunders
# 4                    bogax001             Xander Bogaerts
# ..                        ...                         ...
# 893                  chisj001               Jazz Chisholm
# 894                  lopet001                   Tim Lopes
# 895                  gossp001               Phil Gosselin
# 896                  corrc001               Carlos Correa
# 897                  siscc001                Chance Sisco
#
#      Visiting Team Player 7 Defensive Position Visiting Team Player 8 ID  \
# 0                                            8                  ellia001
# 1                                            7                  uribj002
# 2                                            2                  gordd002
# 3                                            9                  ackld001
# 4                                            6                  piera001
# ..                                         ...                       ...
# 893                                          6                  wallc001
# 894                                          7                  bishb001
# 895                                          3                  kings001
# 896                                          6                  reddj001
# 897                                          2                  valap001
#
#     Visiting Team Player 8 Name  Visiting Team Player 8 Defensive Position  \
# 0                    A.J. Ellis                                          2
# 1                    Juan Uribe                                          5
# 2                    Dee Gordon                                          4
# 3                 Dustin Ackley                                          7
# 4               A.J. Pierzynski                                          2
# ..                          ...                                        ...
# 893                Chad Wallach                                          2
# 894               Braden Bishop                                          9
# 895               Scott Kingery                                          8
# 896                Josh Reddick                                          9
# 897                 Pat Valaika                                          6
#
#     Visiting Team Player 9 ID Visiting Team Player 9 Name  \
# 0                    kersc001             Clayton Kershaw
# 1                    ryu-h001                Hyun-Jin Ryu
# 2                    ryu-h001                Hyun-Jin Ryu
# 3                    zunim001                 Mike Zunino
# 4                    middw001           Will Middlebrooks
# ..                        ...                         ...
# 893                  sierm002            Magneuris Sierra
# 894                  odomj001                 Joseph Odom
# 895                  quinr003                 Roman Quinn
# 896                  garnd001              Dustin Garneau
# 897                  mullc002              Cedric Mullins
#
#      Visiting Team Player 9 Defensive Position Home Team Player 1 ID  \
# 0                                            1              polla001
# 1                                            1              polla001
# 2                                            1              cabre001
# 3                                            2              calhk001
# 4                                            5              markn001
# ..                                         ...                   ...
# 893                                          7              lemad001
# 894                                          2              semim001
# 895                                          9              tsuty001
# 896                                          2              choos001
# 897                                          8              biggc002
#
#     Home Team Player 1 Name  Home Team Player 1 Defensive Position  \
# 0              A.J. Pollock                                      8
# 1              A.J. Pollock                                      8
# 2            Everth Cabrera                                      6
# 3              Kole Calhoun                                      9
# 4             Nick Markakis                                      9
# ..                      ...                                    ...
# 893             DJ LeMahieu                                      3
# 894           Marcus Semien                                      6
# 895          Yoshi Tsutsugo                                      5
# 896           Shin-Soo Choo                                     10
# 897            Cavan Biggio                                      5
#
#     Home Team Player 2 ID Home Team Player 2 Name  \
# 0                hilla001              Aaron Hill
# 1                hilla001              Aaron Hill
# 2                denoc001          Chris Denorfia
# 3                troum001              Mike Trout
# 4                hardj003              J.J. Hardy
# ..                    ...                     ...
# 893              judga001             Aaron Judge
# 894              lastt001         Tommy La Stella
# 895              loweb001            Brandon Lowe
# 896              tavel001           Leody Taveras
# 897              bichb001             Bo Bichette
#
#      Home Team Player 2 Defensive Position Home Team Player 3 ID  \
# 0                                        4              goldp001
# 1                                        4              goldp001
# 2                                        9              headc001
# 3                                        8              pujoa001
# 4                                        6              jonea003
# ..                                     ...                   ...
# 893                                      9              hicka001
# 894                                      4              davik003
# 895                                     10              arozr001
# 896                                      8              kinei001
# 897                                      6              guerv002
#
#     Home Team Player 3 Name  Home Team Player 3 Defensive Position  \
# 0          Paul Goldschmidt                                      3
# 1          Paul Goldschmidt                                      3
# 2             Chase Headley                                      5
# 3             Albert Pujols                                      3
# 4                Adam Jones                                      8
# ..                      ...                                    ...
# 893             Aaron Hicks                                      8
# 894             Khris Davis                                     10
# 895         Randy Arozarena                                      7
# 896      Isiah Kiner-Falefa                                      5
# 897       Vladimir Guerrero                                     10
#
#     Home Team Player 4 ID Home Team Player 4 Name  \
# 0                pradm001            Martin Prado
# 1                pradm001            Martin Prado
# 2                gyorj001             Jedd Gyorko
# 3                hamij003           Josh Hamilton
# 4                davic003             Chris Davis
# ..                    ...                     ...
# 893              voitl001               Luke Voit
# 894              canhm001              Mark Canha
# 895              lowen001               Nate Lowe
# 896              gallj002              Joey Gallo
# 897              gricr001          Randal Grichuk
#
#      Home Team Player 4 Defensive Position Home Team Player 5 ID  \
# 0                                        5              trumm001
# 1                                        5              montm001
# 2                                        4              alony001
# 3                                        7              freed001
# 4                                        3              cruzn002
# ..                                     ...                   ...
# 893                                     10              urshg001
# 894                                      7              olsom001
# 895                                      3              wendj002
# 896                                      9              solan001
# 897                                      8              gurrl001
#
#     Home Team Player 5 Name  Home Team Player 5 Defensive Position  \
# 0               Mark Trumbo                                      7
# 1            Miguel Montero                                      2
# 2             Yonder Alonso                                      3
# 3              David Freese                                      5
# 4               Nelson Cruz                                      7
# ..                      ...                                    ...
# 893        Giovanny Urshela                                      5
# 894              Matt Olson                                      3
# 895             Joey Wendle                                      6
# 896              Nick Solak                                      7
# 897         Lourdes Gurriel                                      7
#
#     Home Team Player 6 ID Home Team Player 6 Name  \
# 0                montm001          Miguel Montero
# 1                trumm001             Mark Trumbo
# 2                medit001            Tommy Medica
# 3                ibanr001             Raul Ibanez
# 4                wietm001            Matt Wieters
# ..                    ...                     ...
# 893              torrg001          Gleyber Torres
# 894              laurr001          Ramon Laureano
# 895              renfh001          Hunter Renfroe
# 896              odorr001            Rougned Odor
# 897              shawt001             Travis Shaw
#
#      Home Team Player 6 Defensive Position Home Team Player 7 ID  \
# 0                                        2              owinc001
# 1                                        7              parrg001
# 2                                        7              venaw001
# 3                                       10              kendh001
# 4                                        2              yound003
# ..                                     ...                   ...
# 893                                      6              gardb001
# 894                                      8              piscs001
# 895                                      9              philb002
# 896                                      4              huffs001
# 897                                      3              villj001
#
#     Home Team Player 7 Name  Home Team Player 7 Defensive Position  \
# 0              Chris Owings                                      6
# 1             Gerardo Parra                                      9
# 2              Will Venable                                      8
# 3            Howie Kendrick                                      4
# 4              Delmon Young                                     10
# ..                      ...                                    ...
# 893           Brett Gardner                                      7
# 894        Stephen Piscotty                                      9
# 895          Brett Phillips                                      8
# 896                Sam Huff                                      2
# 897         Jonathan Villar                                      4
#
#     Home Team Player 8 ID Home Team Player 8 Name  \
# 0                parrg001           Gerardo Parra
# 1                gregd001          Didi Gregorius
# 2                river003             Rene Rivera
# 3                iannc001          Chris Iannetta
# 4                flahr001           Ryan Flaherty
# ..                    ...                     ...
# 893              sancg002            Gary Sanchez
# 894              lambj001               Jake Lamb
# 895              brosm001        Michael Brosseau
# 896              guzmr001           Ronald Guzman
# 897              davij007          Jonathan Davis
#
#      Home Team Player 8 Defensive Position Home Team Player 9 ID  \
# 0                                        9              milew001
# 1                                        6              cahit001
# 2                                        2              casha001
# 3                                        2              aybae001
# 4                                        5              schoj001
# ..                                     ...                   ...
# 893                                      2              wadet002
# 894                                      5              murps001
# 895                                      4              perem005
# 896                                      3              tejea001
# 897                                      9              jansd001
#
#     Home Team Player 9 Name  Home Team Player 9 Defensive Position  \
# 0                Wade Miley                                      1
# 1             Trevor Cahill                                      1
# 2            Andrew Cashner                                      1
# 3               Erick Aybar                                      6
# 4           Jonathan Schoop                                      4
# ..                      ...                                    ...
# 893              Tyler Wade                                      4
# 894             Sean Murphy                                      2
# 895           Michael Perez                                      2
# 896         Anderson Tejeda                                      6
# 897            Danny Jansen                                      2
#
#     Miscellaneous Acquisition Information
# 0             NaN                       Y
# 1             NaN                       Y
# 2             NaN                       Y
# 3             NaN                       Y
# 4             NaN                       Y
# ..            ...                     ...
# 893           NaN                       Y
# 894           NaN                       Y
# 895           NaN                       Y
# 896           NaN                       Y
# 897           NaN                       Y
#
# [15475 rows x 161 columns]

# %%
def get_team_games(teams_games_dir=PATH_TO_TEAM_GAMES):
    """Function that gets the team stats for each team"""
    
    def generate_date(date_of_game):
        """Helper function that parses a game id for the date"""
        
        date_of_game = str(date_of_game)
        
        # Parse the date
        year = int(date_of_game[0:4])
        month = int(date_of_game[4:6])
        day = int(date_of_game[6:8])
        
        return date(year, month, day)
    
    team_stats = dict()
    
    for file in os.listdir(teams_games_dir):
        df = pd.read_csv(os.path.join(teams_games_dir, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Date']), axis=1)
        df.rename(columns={'Earned Runs': 'Team Earned Runs'}, inplace=True)
        team_stats[file[0:3]] = df.sort_values(by=['Date', 'Number of game']).reset_index(drop=True)

    return team_stats

# %%
def get_team_rolling_sums(team_games, window=14):
    """Function that calculates the rolling statistics for each team"""
    
    for _, df in team_games.items():
        for col in df.columns[6::]:
            df[f'{col} {window} Game Window'] = df[col].rolling(window).sum()
            df[f'{col} {window} Game Window'] = df[f'{col} {window} Game Window'].shift(1)
        
        df.drop(columns=df.columns[3:33], inplace=True)
        
        # Add BA
        df[f'BA {window} Game Window'] = (df[f'Hits {window} Game Window'] /
                                          df[f'At-bats {window} Game Window'])
        
        # Add SLG = (1B + 2Bx2 + 3Bx3 + HRx4)/AB.
        df[f'SLG {window} Game Window'] = ((df[f'Hits {window} Game Window'] +
                                            df[f'Doubles {window} Game Window'] +
                                            2 * df[f'Triples {window} Game Window'] +
                                            3 * df[f'Homeruns {window} Game Window']) /
                                           df[f'At-bats {window} Game Window'])
        
        # Add OBP = (Hits + Walks + Hit by Pitch) / (At Bats + Walks + Hit by Pitch + Sacrifice Flies
        df[f'OBP {window} Game Window'] = ((df[f'Hits {window} Game Window'] +
                                            df[f'Walks {window} Game Window'] +
                                            df[f'Hit-by-pitch {window} Game Window']) /
                                           (df[f'At-bats {window} Game Window'] + 
                                            df[f'Walks {window} Game Window'] +
                                            df[f'Hit-by-pitch {window} Game Window'] +
                                            df[f'Sacrifice Flies {window} Game Window']))
        
        # OPS = OBS + SLG
        df[f'OPS {window} Game Window'] = (df[f'OBP {window} Game Window'] +
                                           df[f'SLG {window} Game Window'])
        
        # ISO = SLG - BA
        df[f'ISO {window} Game Window'] = (df[f'SLG {window} Game Window'] -
                                           df[f'BA {window} Game Window'])
        
        # Drop stats that won't be needed
        df.drop(columns=(list(df.columns[5:8]) +
                         list(df.columns[9:21]) +
                         list(df.columns[22:30])),
                inplace=True)
        
        df.dropna(inplace=True)
        df.reset_index(drop=True, inplace=True)
            
    return team_games

# %%
# Save the rolling stats, 14 games seems like the sweet spot
clean_dir(TEAM_ROLLING_SUMS_DIR)
for team, df in get_team_rolling_sums(get_team_games(), window=14).items():
    df.to_csv(os.path.join(TEAM_ROLLING_SUMS_DIR, f'{team}.csv'), index=False)

# %%
pd.read_csv(os.path.join(TEAM_ROLLING_SUMS_DIR, 'NYA.csv')) # just to see
# Out:
#             Date  Number of game Team  At-bats 14 Game Window  \
# 0     2014-04-16               2  NYA                   463.0
# 1     2014-04-17               0  NYA                   468.0
# 2     2014-04-18               0  NYA                   477.0
# 3     2014-04-19               0  NYA                   481.0
# 4     2014-04-20               0  NYA                   470.0
# ...          ...             ...  ...                     ...
# 1013  2020-09-23               0  NYA                   474.0
# 1014  2020-09-24               0  NYA                   475.0
# 1015  2020-09-25               0  NYA                   474.0
# 1016  2020-09-26               0  NYA                   481.0
# 1017  2020-09-27               0  NYA                   485.0
#
#       Hits 14 Game Window  RBIs 14 Game Window  \
# 0                   124.0                 49.0
# 1                   130.0                 49.0
# 2                   139.0                 59.0
# 3                   140.0                 60.0
# 4                   127.0                 54.0
# ...                   ...                  ...
# 1013                136.0                102.0
# 1014                135.0                101.0
# 1015                135.0                 95.0
# 1016                133.0                 92.0
# 1017                133.0                 93.0
#
#       Team Earned Runs 14 Game Window  BA 14 Game Window  SLG 14 Game Window  \
# 0                                53.0           0.267819            0.423326
# 1                                47.0           0.277778            0.431624
# 2                                45.0           0.291405            0.475891
# 3                                54.0           0.291060            0.471933
# 4                                66.0           0.270213            0.444681
# ...                               ...                ...                 ...
# 1013                             46.0           0.286920            0.550633
# 1014                             55.0           0.284211            0.545263
# 1015                             57.0           0.284810            0.533755
# 1016                             60.0           0.276507            0.505198
# 1017                             63.0           0.274227            0.507216
#
#       OBP 14 Game Window  OPS 14 Game Window  ISO 14 Game Window
# 0               0.332031            0.755357            0.155508
# 1               0.335283            0.766907            0.153846
# 2               0.343570            0.819461            0.184486
# 3               0.342256            0.814190            0.180873
# 4               0.318898            0.763578            0.174468
# ...                  ...                 ...                 ...
# 1013            0.378623            0.929256            0.263713
# 1014            0.374545            0.919809            0.261053
# 1015            0.372943            0.906699            0.248945
# 1016            0.366906            0.872104            0.228690
# 1017            0.367673            0.874890            0.232990
#
# [1018 rows x 12 columns]

# %% [markdown]
# Now we need to add the pitcher data

# %%
def get_pitching_stats(directory=PATH_TO_PITCHER_STATS):
    """Function returns a dictionary, where each key is a player_id
    and each value is a dataframe object containing the player's stats"""
    
    def generate_date(game_id):
        """Helper function that parses a game id for the date"""
        
        # Parse the game_id
        year = int(game_id[3:7])
        month = int(game_id[7:9])
        day = int(game_id[9:11])
        
        return date(year, month, day)
    
    def generate_game_number(game_id):
        """Helper function that parses a game id and returns the game number"""
        return int(game_id[-1])        
    
    player_stats_dict = dict()
    
    for file in tqdm(os.listdir(directory), unit='players', desc='Fetching Pitcher Stats'):
        df = pd.read_csv(os.path.join(directory, file))
        df['Date'] = df.apply(lambda row : generate_date(row['Game ID']), axis=1) 
        df['Game Number'] = df.apply(lambda row : generate_game_number(row['Game ID']), axis=1)
        df['ID'] = file[0:-4]
        df.drop(columns=['Unnamed: 0'], inplace=True)
        player_id = df.iloc[0]['ID']
        player_stats_dict[player_id] = df.sort_values(by=['Date', 'Game Number']).reset_index(drop=True)
    
    return player_stats_dict

# %%
get_pitching_stats()['kersc001']
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value='')))
#           Game ID        ID  Balls  Strikes  Homeruns Allowed  Hits Allowed  \
# 0    ARI201403220  kersc001     28       40                 0             5
# 1    WAS201405060  kersc001     21       36                 0             9
# 2    LAN201405110  kersc001     26       30                 1             7
# 3    ARI201405170  kersc001     20       16                 0             6
# 4    PHI201405230  kersc001     30       39                 0             2
# ..            ...       ...    ...      ...               ...           ...
# 167  LAN202009030  kersc001     28       35                 0             1
# 168  ARI202009090  kersc001     28       32                 0             4
# 169  SDN202009140  kersc001     26       42                 1             5
# 170  COL202009190  kersc001     27       28                 0             4
# 171  LAN202009250  kersc001     23       26                 2             8
#
#      Strikeouts  Pickoff Errors  Pickoffs  Wild Pitches  Balks  Walks  \
# 0             7               0         0             1      0      1
# 1             9               0         1             0      0      0
# 2             9               0         0             0      0      0
# 3             3               0         0             0      1      2
# 4             9               0         0             0      0      3
# ..          ...             ...       ...           ...    ...    ...
# 167           8               0         0             0      0      2
# 168           3               0         0             0      0      2
# 169           9               0         0             0      0      0
# 170           6               0         1             0      0      0
# 171           3               0         0             0      0      0
#
#      Intentional Walks  Hit by Pitch  Earned Runs  Innings Pitched  \
# 0                    0             0            1         6.666667
# 1                    0             0            0         7.000000
# 2                    0             0            3         7.000000
# 3                    0             0            6         1.666667
# 4                    0             0            0         6.000000
# ..                 ...           ...          ...              ...
# 167                  0             1            0         6.000000
# 168                  0             0            3         5.000000
# 169                  0             0            1         6.333333
# 170                  0             0            1         6.666667
# 171                  0             0            1         4.000000
#
#            Date  Game Number
# 0    2014-03-22            0
# 1    2014-05-06            0
# 2    2014-05-11            0
# 3    2014-05-17            0
# 4    2014-05-23            0
# ..          ...          ...
# 167  2020-09-03            0
# 168  2020-09-09            0
# 169  2020-09-14            0
# 170  2020-09-19            0
# 171  2020-09-25            0
#
# [172 rows x 18 columns]

# %%
def get_pitching_rolling_sums(dictionary, window=10):
    """Function that will generate statsistics based on a rolling window"""
    
    for k, df in tqdm(dictionary.items(), unit='players', desc='Generating Rolling Pitcher Stats'):
        df = df.copy()
        
        for col in df.columns:
            if col in {'Game ID', 'ID', 'Date', 'Game Number'}:
                continue

            df[f'{col} {window} Game Window'] = df[col].rolling(window).sum()
            df[f'{col} {window} Game Window'] = df[f'{col} {window} Game Window'].shift(1)
        
        # Calculate ERA
        df[f'ERA {window} Game Window'] = ((df[f'Earned Runs {window} Game Window'] * 9) /
                                           df[f'Innings Pitched {window} Game Window'])
        
        # Calculate WHIP
        # (Walks + hits) / innings pitched
        df[f'WHIP {window} Game Window'] = ((df[f'Hits Allowed {window} Game Window'] +
                                             df[f'Walks {window} Game Window']) /
                                            (df[f'Innings Pitched {window} Game Window']))
        
        # Calculate FIP
        # (13 * HR + 3*(BB + HBP) - 2*K) / IP + constant
        df[f'FIP {window} Game Window'] = (((13 * df[f'Homeruns Allowed {window} Game Window']) +
                                             (3 * (df[f'Walks {window} Game Window'] +
                                                   df[f'Hit by Pitch {window} Game Window'])) -
                                             (2 * df[f'Strikeouts {window} Game Window'])) /
                                            (df[f'Innings Pitched {window} Game Window'])) + 3.2

        df = df.filter(items=['Game ID',
                              'ID',
                              'Date',
                              'Game Number',
                              f'Homeruns Allowed {window} Game Window',
                              f'Hits Allowed {window} Game Window',
                              f'Strikeouts {window} Game Window',
                              f'Walks {window} Game Window',
                              f'Earned Runs {window} Game Window',
                              f'ERA {window} Game Window',
                              f'WHIP {window} Game Window',
                              f'FIP {window} Game Window'])
    
        df.dropna(inplace=True)
        
        dictionary[k] = df
    
    return dictionary

# %%
# Save the rolling stats, 10 games seems like the sweet spot
clean_dir(PITCHING_ROLLING_SUMS_DIR)
for pitcher, df in get_pitching_rolling_sums(get_pitching_stats(), window=10).items():
    df.to_csv(os.path.join(PITCHING_ROLLING_SUMS_DIR, f'{pitcher}.csv'), index=False)
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value='')))
# HBox(children=(HTML(value='Generating Rolling Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value…

# %%
pd.read_csv(os.path.join(PITCHING_ROLLING_SUMS_DIR, 'kersc001.csv'))
# Out:
#           Game ID        ID        Date  Game Number  \
# 0    KCA201406240  kersc001  2014-06-24            0
# 1    LAN201406290  kersc001  2014-06-29            0
# 2    COL201407040  kersc001  2014-07-04            0
# 3    LAN201407100  kersc001  2014-07-10            0
# 4    SLN201407200  kersc001  2014-07-20            0
# ..            ...       ...         ...          ...
# 157  LAN202009030  kersc001  2020-09-03            0
# 158  ARI202009090  kersc001  2020-09-09            0
# 159  SDN202009140  kersc001  2020-09-14            0
# 160  COL202009190  kersc001  2020-09-19            0
# 161  LAN202009250  kersc001  2020-09-25            0
#
#      Homeruns Allowed 10 Game Window  Hits Allowed 10 Game Window  \
# 0                                4.0                         51.0
# 1                                4.0                         52.0
# 2                                4.0                         48.0
# 3                                3.0                         43.0
# 4                                4.0                         40.0
# ..                               ...                          ...
# 157                             12.0                         45.0
# 158                             10.0                         41.0
# 159                              9.0                         38.0
# 160                              9.0                         39.0
# 161                              6.0                         35.0
#
#      Strikeouts 10 Game Window  Walks 10 Game Window  \
# 0                         86.0                   8.0
# 1                         87.0                   8.0
# 2                         91.0                  10.0
# 3                         90.0                  11.0
# 4                         98.0                  10.0
# ..                         ...                   ...
# 157                       62.0                  14.0
# 158                       64.0                  14.0
# 159                       61.0                  13.0
# 160                       65.0                  10.0
# 161                       66.0                   9.0
#
#      Earned Runs 10 Game Window  ERA 10 Game Window  WHIP 10 Game Window  \
# 0                          17.0            2.378238             0.917098
# 1                          16.0            2.192893             0.913706
# 2                          16.0            2.192893             0.883249
# 3                          13.0            1.755000             0.810000
# 4                           8.0            0.972973             0.675676
# ..                          ...                 ...                  ...
# 157                        17.0            2.668605             1.029070
# 158                        12.0            1.851429             0.942857
# 159                        14.0            2.123596             0.859551
# 160                        14.0            2.123596             0.825843
# 161                        11.0            1.650000             0.733333
#
#      FIP 10 Game Window
# 0              1.707772
# 1              1.707614
# 2              1.677157
# 3              1.580000
# 4              1.659459
# ..                  ...
# 157            4.490698
# 158            4.005714
# 159            3.823596
# 160            3.537079
# 161            2.800000
#
# [162 rows x 12 columns]

# %%
columns = ['Date',
           'Number of game',
           'Visiting Team',
           'Visiting Team Game Number',
           'Home Team',
           'Home Team Game Number',
           'Visiting Team Score',
           'Home Team Score',
           'Visiting Team Starting Pitcher ID',
           'Home Team Starting Pitcher ID']

filtered_game_logs = game_logs.filter(items=columns)
filtered_game_logs
# Out:
#            Date  Number of game Visiting Team  Visiting Team Game Number  \
# 0    2014-03-22               0           LAN                          1
# 1    2014-03-23               0           LAN                          2
# 2    2014-03-30               0           LAN                          3
# 3    2014-03-31               0           SEA                          1
# 4    2014-03-31               0           BOS                          1
# ..          ...             ...           ...                        ...
# 893  2020-09-27               0           MIA                         60
# 894  2020-09-27               0           SEA                         60
# 895  2020-09-27               0           PHI                         60
# 896  2020-09-27               0           HOU                         60
# 897  2020-09-27               0           BAL                         60
#
#     Home Team  Home Team Game Number  Visiting Team Score  Home Team Score  \
# 0         ARI                      1                    3                1
# 1         ARI                      2                    7                5
# 2         SDN                      1                    1                3
# 3         ANA                      1                   10                3
# 4         BAL                      1                    1                2
# ..        ...                    ...                  ...              ...
# 893       NYA                     60                    5                0
# 894       OAK                     60                    2                6
# 895       TBA                     60                    0                5
# 896       TEX                     60                    4                8
# 897       TOR                     60                    7                5
#
#     Visiting Team Starting Pitcher ID Home Team Starting Pitcher ID
# 0                            kersc001                      milew001
# 1                            ryu-h001                      cahit001
# 2                            ryu-h001                      casha001
# 3                            hernf002                      weavj003
# 4                            lestj001                      tillc001
# ..                                ...                           ...
# 893                          urenj001                      schmc002
# 894                          gonzm005                      montf001
# 895                          nolaa001                      flemj001
# 896                          dejoc001                      lylej001
# 897                          akink001                      roart001
#
# [15475 rows x 10 columns]

# %%
def generate_training_data(schedule, team_data, pitching_data):
    """Formats the data for training"""
    
    # Get the batting and pitching stats
    batting = pd.concat([v for k,v in team_data.items()])
    pitching = pd.concat([v for k,v in pitching_data.items()])
    
    # Merge home batting with schedule
    home_batting = pd.merge(schedule,
                            batting,
                            how='left',
                            left_on=['Date', 'Number of game', 'Home Team'],
                            right_on=['Date', 'Number of game', 'Team']).drop(columns=['Team'])
    
    # Merge away batting with schedule
    away_batting = pd.merge(schedule,
                            batting,
                            how='left',
                            left_on=['Date', 'Number of game', 'Visiting Team'],
                            right_on=['Date', 'Number of game', 'Team']).drop(columns=['Team'])
    
    # Merge home pitching with schedule
    home_pitching = pd.merge(schedule,
                             pitching,
                             how='left',
                             left_on=['Date', 'Number of game', 'Home Team Starting Pitcher ID'],
                             right_on=['Date', 'Game Number', 'ID']).drop(columns=['Game Number', 'Game ID', 'ID'])
    
    # Merge away pitching with schedule
    away_pitching = pd.merge(schedule,
                             pitching,
                             how='left',
                             left_on=['Date', 'Number of game', 'Visiting Team Starting Pitcher ID'],
                             right_on=['Date', 'Game Number', 'ID']).drop(columns=['Game Number', 'Game ID', 'ID'])
    
    # Merge home batting with home pitching
    df_home = pd.merge(home_batting,
                       home_pitching,
                       how='left',
                       on=list(schedule.columns))
    
    # Merge away batting with away pitching
    df_away = pd.merge(away_batting,
                       away_pitching,
                       how='left',
                       on=list(schedule.columns))
    
    # Merge home and away
    home_and_away = pd.merge(df_home,
                             df_away,
                             how='left',
                             on=list(schedule.columns))
        
    # Create differences between home and away
    for i, home_col in enumerate(home_and_away.columns[len(schedule.columns):len(df_home.columns)]):
        suffix_index = home_col.find('_')
        col_name = 'Difference ' + home_col[:suffix_index]
        away_col = home_col[:-2] + '_y'
        home_and_away[col_name] = home_and_away[home_col] - home_and_away[away_col]
    
    return home_and_away.drop(columns=list(home_and_away.columns)[len(schedule.columns):
                                                                  2*len(df_home.columns)-len(schedule.columns)]).dropna()

# %%
generate_training_data(filtered_game_logs,
                       get_team_rolling_sums(get_team_games(), window=14),
                       get_pitching_rolling_sums(get_pitching_stats(), window=10))
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value='')))
# HBox(children=(HTML(value='Generating Rolling Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value…
#              Date  Number of game Visiting Team  Visiting Team Game Number  \
# 751    2014-05-26               0           SDN                         52
# 754    2014-05-26               0           BAL                         49
# 763    2014-05-27               0           DET                         48
# 764    2014-05-27               0           ANA                         51
# 766    2014-05-27               0           SDN                         53
# ...           ...             ...           ...                        ...
# 15464  2020-09-27               0           MIL                         60
# 15465  2020-09-27               0           NYN                         60
# 15468  2020-09-27               0           DET                         58
# 15469  2020-09-27               0           CIN                         60
# 15471  2020-09-27               0           SEA                         60
#
#       Home Team  Home Team Game Number  Visiting Team Score  Home Team Score  \
# 751         ARI                     53                    5                7
# 754         MIL                     52                    7                6
# 763         OAK                     52                    6                5
# 764         SEA                     51                    6                4
# 766         ARI                     54                    4                3
# ...         ...                    ...                  ...              ...
# 15464       SLN                     58                    2                5
# 15465       WAS                     60                    5               15
# 15468       KCA                     60                    1                3
# 15469       MIN                     60                    5                3
# 15471       OAK                     60                    2                6
#
#       Visiting Team Starting Pitcher ID Home Team Starting Pitcher ID  \
# 751                            rosst001                      mccab001
# 754                            tillc001                      lohsk001
# 763                            schem001                      grays001
# 764                            weavj003                      eliar001
# 766                            stule002                      milew001
# ...                                 ...                           ...
# 15464                          andeb004                      gomba001
# 15465                          lugos001                      votha001
# 15468                          zimmj003                      singb001
# 15469                          grays001                      hillr001
# 15471                          gonzm005                      montf001
#
#        Difference At-bats 14 Game Window  Difference Hits 14 Game Window  \
# 751                                 23.0                            14.0
# 754                                -19.0                            -7.0
# 763                                -10.0                            -9.0
# 764                                -10.0                            -2.0
# 766                                 23.0                            13.0
# ...                                  ...                             ...
# 15464                              -12.0                           -15.0
# 15465                              -35.0                            -3.0
# 15468                               -6.0                             7.0
# 15469                               27.0                            14.0
# 15471                               -3.0                            -4.0
#
#        Difference RBIs 14 Game Window  \
# 751                              -7.0
# 754                              -6.0
# 763                              20.0
# 764                               4.0
# 766                              -1.0
# ...                               ...
# 15464                           -16.0
# 15465                            10.0
# 15468                            14.0
# 15469                            -3.0
# 15471                            -5.0
#
#        Difference Team Earned Runs 14 Game Window  \
# 751                                           1.0
# 754                                         -14.0
# 763                                         -39.0
# 764                                          10.0
# 766                                           0.0
# ...                                           ...
# 15464                                         6.0
# 15465                                       -10.0
# 15468                                       -17.0
# 15469                                         0.0
# 15471                                         4.0
#
#        Difference BA 14 Game Window  Difference SLG 14 Game Window  \
# 751                        0.018262                       0.027589
# 754                       -0.004130                       0.001457
# 763                       -0.013275                       0.031719
# 764                        0.000965                       0.001635
# 766                        0.016284                       0.019151
# ...                             ...                            ...
# 15464                     -0.030145                      -0.105942
# 15465                      0.013476                       0.014908
# 15468                      0.018250                       0.088779
# 15469                      0.018313                       0.052218
# 15471                     -0.007802                       0.018713
#
#        Difference OBP 14 Game Window  Difference OPS 14 Game Window  \
# 751                        -0.004663                       0.022926
# 754                        -0.002286                      -0.000829
# 763                         0.009795                       0.041514
# 764                        -0.011744                      -0.010109
# 766                         0.003791                       0.022942
# ...                              ...                            ...
# 15464                      -0.038774                      -0.144716
# 15465                       0.007725                       0.022633
# 15468                       0.031292                       0.120071
# 15469                      -0.010839                       0.041379
# 15471                      -0.011315                       0.007398
#
#        Difference ISO 14 Game Window  \
# 751                         0.009327
# 754                         0.005587
# 763                         0.044994
# 764                         0.000670
# 766                         0.002867
# ...                              ...
# 15464                      -0.075797
# 15465                       0.001432
# 15468                       0.070529
# 15469                       0.033905
# 15471                       0.026515
#
#        Difference Homeruns Allowed 10 Game Window  \
# 751                                           3.0
# 754                                           0.0
# 763                                          -2.0
# 764                                          -1.0
# 766                                           0.0
# ...                                           ...
# 15464                                        -3.0
# 15465                                         1.0
# 15468                                        -1.0
# 15469                                        -1.0
# 15471                                         2.0
#
#        Difference Hits Allowed 10 Game Window  \
# 751                                      11.0
# 754                                       0.0
# 763                                      -2.0
# 764                                       6.0
# 766                                      -9.0
# ...                                       ...
# 15464                                     7.0
# 15465                                     0.0
# 15468                                   -15.0
# 15469                                   -13.0
# 15471                                     0.0
#
#        Difference Strikeouts 10 Game Window  Difference Walks 10 Game Window  \
# 751                                    -6.0                            -16.0
# 754                                    10.0                            -10.0
# 763                                   -23.0                              2.0
# 764                                     2.0                              6.0
# 766                                    19.0                             15.0
# ...                                     ...                              ...
# 15464                                  13.0                              5.0
# 15465                                 -19.0                              6.0
# 15468                                  10.0                             16.0
# 15469                                 -30.0                             -2.0
# 15471                                 -12.0                             15.0
#
#        Difference Earned Runs 10 Game Window  Difference ERA 10 Game Window  \
# 751                                     13.0                       2.019170
# 754                                     -6.0                      -1.384536
# 763                                     -4.0                      -0.618767
# 764                                      5.0                       1.094026
# 766                                      6.0                      -0.167401
# ...                                      ...                            ...
# 15464                                   -2.0                      -0.187606
# 15465                                    7.0                       1.388756
# 15468                                   -8.0                      -1.845465
# 15469                                   -5.0                      -0.192681
# 15471                                   10.0                       2.987787
#
#        Difference WHIP 10 Game Window  Difference FIP 10 Game Window
# 751                         -0.020897                       0.076484
# 754                         -0.350169                      -0.929291
# 763                         -0.038668                       0.432741
# 764                          0.335152                       0.144589
# 766                         -0.216072                      -0.209665
# ...                               ...                            ...
# 15464                        0.322254                      -1.187887
# 15465                        0.125427                       1.749487
# 15468                       -0.085262                       0.191742
# 15469                       -0.016271                       1.065997
# 15471                        0.668616                       1.937010
#
# [10695 rows x 27 columns]

# %% [markdown]
# # Training a Random Forrest Classifier

# %%
data = generate_training_data(filtered_game_logs,
                              get_team_rolling_sums(get_team_games(), window=14),
                              get_pitching_rolling_sums(get_pitching_stats(), window=10))

training_data = data.dropna().reset_index(drop=True)
training_data['Winner'] = np.where(training_data["Home Team Score"] >
                                   training_data["Visiting Team Score"], 1, 0)
training_data.drop(columns=['Date',
                            'Number of game',
                            'Visiting Team',
                            'Visiting Team Game Number',
                            'Home Team',
                            'Home Team Game Number',
                            'Home Team Score',
                            'Visiting Team Score',
                            'Visiting Team Starting Pitcher ID',
                            'Home Team Starting Pitcher ID'],
                   inplace=True)

X_train, X_test, y_train, y_test = train_test_split(training_data.drop(columns=['Winner']),
                                                    training_data.filter(items=['Winner']).pop('Winner'),
                                                    random_state=42)
# Out:
# HBox(children=(HTML(value='Fetching Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value='')))
# HBox(children=(HTML(value='Generating Rolling Pitcher Stats'), FloatProgress(value=0.0, max=817.0), HTML(value…

# %%
# Number of trees in random forest
n_estimators = [i for i in range(100, 1100, 100)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [i for i in range(1, 21)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_param_grid = {'n_estimators': n_estimators,
                      'max_features': max_features,
                      'max_depth': max_depth,
                      'min_samples_split': min_samples_split,
                      'min_samples_leaf': min_samples_leaf,
                      'bootstrap': bootstrap}
# Use the random grid to find the best hyperparameters
# First create the base model to tune
rf = RandomForestClassifier()

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf,
                               param_distributions = random_param_grid,
                               n_iter = 50,
                               cv = 3,
                               verbose = 2,
                               random_state = 42,
                               n_jobs = -1)

# Fit the random search model
rf_random.fit(X_train, y_train)

# %%
rf_random.best_params_

# %%
best_params = {'n_estimators': 800,
               'min_samples_split': 2,
               'min_samples_leaf': 4,
               'max_features': 'sqrt',
               'max_depth': 2,
               'bootstrap': False,
               'random_state': 42}

# %%
rf = RandomForestClassifier(**best_params)
rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 0.5719985039271911

# %%
rf.score(X_test, y_test)
# Out:
# 0.5732984293193717

# %%
clean_dir(MODEL_SAVE_DIR)

pickle.dump(rf, open(os.path.join(MODEL_SAVE_DIR, 'rfcl.sav'), 'wb'))

# %% [markdown]
# # Gaussian Bayes Naive Bayes Model

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
gnb.score(X_train, y_train)
# Out:
# 0.5550430120932552

# %%
gnb.score(X_test, y_test)
# Out:
# 0.5635751682872102

# %% [markdown]
# # Neural Network Model

# %%
nn_data = generate_training_data(filtered_game_logs,
                                 get_team_rolling_sums(get_team_games(), window=14),
                                 get_pitching_rolling_sums(get_pitching_stats(), window=10))

# %%
nn_data.head()

# %%
nn_training_data = nn_data.dropna().reset_index(drop=True)
nn_training_data['Winner'] = np.where(nn_training_data["Home Team Score"] >
                                      nn_training_data["Visiting Team Score"], 1, 0)

nn_training_data.drop(columns=['Date',
                               'Number of game',
                               'Visiting Team',
                               'Visiting Team Game Number',
                               'Home Team',
                               'Home Team Game Number',
                               'Home Team Score',
                               'Visiting Team Score',
                               'Visiting Team Starting Pitcher ID',
                               'Home Team Starting Pitcher ID'],
                      inplace=True)

nn_training_data.head()

# %% [markdown]
# ## Getting the Data Ready for Tensorflow
# Now we have our training set and our test set. Before we can train a model, we must first get the dataframe objects properly ready and also correctly identify the feature columns we will be using.

# %% [markdown]
# First, we have to wrap the dataframes with `tf.data`, in order to shuffle and batch the data.

# %%
# A utility method to create a tf.data dataset from a Pandas Dataframe
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
    dataframe = dataframe.copy()
    labels = dataframe.pop('Winner')
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    ds = ds.prefetch(batch_size)
    return ds

# %%
# Split the data into training sets and test sets
train, test = train_test_split(nn_training_data, test_size=0.25)
train, val = train_test_split(train, test_size=0.2)

# %% [markdown]
# We have now created the input pipeline. Let's call it to see the format of the data it returns. For demonstration purposes, we will enter a small batch size to keep the output readable and also only show the first three features.

# %%
train_ds = df_to_dataset(train, batch_size=5)

[(train_features, label_batch)] = train_ds.take(1)
print('Every feature:', list(train_features.keys())[:3])

# %% [markdown]
# In this dataset, all of our features are Numeric. For each Numeric feature, we will have to use a `Normalization()` layer to make sure that the mean of each feature is a 0 and its standard deviation is 1.

# %%
# A utility method to create a Normalization Layer
def get_normalization_layer(name, dataset):
    # Create a Normalization layer for our feature.
    normalizer = preprocessing.Normalization()

    # Prepare a Dataset that only yields our feature.
    feature_ds = dataset.map(lambda x, y: x[name])

    # Learn the statistics of the data.
    normalizer.adapt(feature_ds)

    return normalizer

# %%
batch_size=64
train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, shuffle=False, batch_size=batch_size)
test_ds = df_to_dataset(test, shuffle=False, batch_size=batch_size)

# %%
all_inputs = []
encoded_features = []

for header in tqdm(list(train_features.keys()), unit="feature"):
    numeric_column = tf.keras.Input(shape=(1,), name=header)
    normalization_layer = get_normalization_layer(header, train_ds)
    encoded_numeric_column = normalization_layer(numeric_column)
    all_inputs.append(numeric_column)
    encoded_features.append(encoded_numeric_column)

# %%
all_features = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(64, activation="relu")(all_features)
x = tf.keras.layers.Dense(32, activation="relu")(x)
x = tf.keras.layers.Dense(16, activation="relu")(x)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(1)(x)
model = tf.keras.Model(all_inputs, output)
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=["accuracy"])

# %%
model.fit(train_ds, epochs=40, validation_data=val_ds)

# %% [markdown]
# # Testing loading the Random Forest Model
# In this section, we will see how to use the model by loading it from memory. We will also create a function that takes in as input two teams and two pitchers, a home team, a home pitcher, an away team, and an away pitcher. It will output the probability each team will win with. We will use the latest data for all inputted values.

# %% [markdown]
# ## 2020 Data
# Here, we are simply going to get the last rolling sum for each pitcher and each team, this is what we will use on the website.

# %%
clean_dir(DATA_2020) # Clear the directory

recent_team_dfs=[]
recent_pitcher_dfs=[]

# Get the most recent team rollings sums
for teamfile in os.listdir(TEAM_ROLLING_SUMS_DIR):
    recent_team_dfs.append(pd.read_csv(os.path.join(TEAM_ROLLING_SUMS_DIR, teamfile)).tail(1).reset_index(drop=True))
    
# Get the most recent pitcher rolling sums
for player in os.listdir(PITCHING_ROLLING_SUMS_DIR):
    recent_pitcher_dfs.append(pd.read_csv(os.path.join(PITCHING_ROLLING_SUMS_DIR, player)).tail(1).reset_index(drop=True))

# Create a dataframe for both
recent_teams = pd.concat(recent_team_dfs, ignore_index=True).reset_index(drop=True).sort_values(by=['Team'])
recent_pitchers = pd.concat(recent_pitcher_dfs, ignore_index=True).reset_index(drop=True).sort_values(by=['ID'])

# Clean the sub directories
clean_dir(os.path.join(DATA_2020, 'teams'))
clean_dir(os.path.join(DATA_2020, 'pitchers'))

# Save the dataframes
recent_teams.to_csv(os.path.join(LATEST_TEAM_DIR, 'teams.csv'), index=False)
recent_pitchers.to_csv(os.path.join(LATEST_PITCHER_DIR, 'pitchers.csv'), index=False)

# %% [markdown]
# ## Make a Prediction using 2020 Data

# %%
def make_prediction(home_team, away_team, home_pitcher, away_pitcher):
    """Function that returns the probability of the home team winning
    
    Parameters:
        - home_team: String of the home team's identifying abbreviation
        - away_team: String of the away team's identifying abbreviation
        - home_pitcher: String of home pitcher's player id
        - away_pitcher: String of away pitcher's player id
    """
    
    clf = pickle.load(open(os.path.join(MODEL_SAVE_DIR, 'rfcl.sav'), 'rb'))
    teams = pd.read_csv(os.path.join(LATEST_TEAM_DIR, 'teams.csv'))
    pitchers = pd.read_csv(os.path.join(LATEST_PITCHER_DIR, 'pitchers.csv'))
    
    # Columns to drop for the team stats
    team_dropping_columns = ['Date', 'Number of game', 'Team']
    
    # Load in home team and away team; reset index so we can subtract from them
    home_team_df = teams.loc[teams['Team'] == home_team].drop(columns=team_dropping_columns)
    home_team_df.reset_index(drop=True, inplace=True)
    
    away_team_df = teams.loc[teams['Team'] == away_team].drop(columns=team_dropping_columns)
    away_team_df.reset_index(drop=True, inplace=True)
    
    # Get home team - away team; reset index so we can merge it with the pitching stats
    team_differences_df = (home_team_df - away_team_df).reset_index(drop=True)
    

    # Columns to drop for the pitcher stats
    pitcher_dropping_columns = ['Game ID', 'Date', 'Game Number', 'ID']
    
    # Load in home and away pitchers; reset index so we can subtract from them
    home_pitcher_df = pitchers.loc[pitchers['ID'] == home_pitcher].drop(columns=pitcher_dropping_columns)
    home_pitcher_df.reset_index(drop=True, inplace=True)
    
    away_pitcher_df = pitchers.loc[pitchers['ID'] == away_pitcher].drop(columns=pitcher_dropping_columns)
    away_pitcher_df.reset_index(drop=True, inplace=True)
    
    # Get home pitcher - away pitcher; reset index so we can merge it with team stats
    pitcher_differences_df = (home_pitcher_df - away_pitcher_df).reset_index(drop=True)
    
    # Datapoint as input for the model
    datapoint = pd.concat([team_differences_df, pitcher_differences_df], axis=1)
    
    # Return the prediction
    return clf.predict_proba(datapoint)[0]

# %%
make_prediction('NYA', 'BOS', 'coleg001', 'eovan001')
# Out:
# array([0.41235047, 0.58764953])
