# %% [markdown]
# # Imports

# %%
from sportsreference.mlb.schedule import Schedule
from sportsreference.mlb.teams import Teams
from tqdm.notebook import tqdm

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load Data

# %% [markdown]
# We first need to load in the data. We can get the sports reference data by running `get_game_boxes.py` file in the SportsReference folder. Thne let's create one giant csv that has all of the games from all seasons.

# %%
SR_BOXES = './datasets/sports_reference_boxes/'

def getAllBoxes(boxes_dir=SR_BOXES):
    """Function that returns all of the game box scores"""
    
    dfs = []
    for year in os.listdir(boxes_dir):
        year_dir = os.path.join(boxes_dir, year)
        for file in os.listdir(year_dir):
            team_df = pd.read_csv(os.path.join(year_dir, file), index_col=0)
            team_df.index.name = 'game_id'
            dfs.append(team_df)

    return pd.concat(dfs).sort_values(by=['date', 'time']).drop_duplicates()

# %% [markdown]
# # Compute Moving Average

# %%
# Get all the boxscores in one dataframe
allBoxes = getAllBoxes()

# Get all the team abbreviations, this is how we will identify teams
TEAMS = set(allBoxes['winning_abbr']).union(set(allBoxes['losing_abbr']))

# Create an away column and a home column
allBoxes['away'] = np.where(allBoxes['winner'] == 'Away',
                            allBoxes['winning_abbr'],
                            allBoxes['losing_abbr'])

allBoxes['home'] = np.where(allBoxes['winner'] == 'Home',
                            allBoxes['winning_abbr'],
                            allBoxes['losing_abbr'])

# labels we are going to keep, we get rid of any overages because taking the average
# of an average is generally incorrect
keeping_labels = ['date',
                  'away',
                  'home',
                  'winner',
                  'away_at_bats',
                  'away_runs',
                  'away_hits',
                  'away_rbi',
                  'away_earned_runs',
                  'away_bases_on_balls',
                  'away_strikeouts',
                  'away_plate_appearances',
                  'away_pitches',
                  'away_strikes',
                  'away_base_out_runs_added',
                  'away_putouts',
                  'away_assists',
                  'away_innings_pitched',
                  'away_home_runs',
                  'away_strikes_by_contact',
                  'away_strikes_swinging',
                  'away_strikes_looking',
                  'away_grounded_balls',
                  'away_fly_balls',
                  'away_line_drives',
                  'away_game_score',
                  'away_base_out_runs_saved',
                  'home_at_bats',
                  'home_runs',
                  'home_hits',
                  'home_rbi',
                  'home_earned_runs',
                  'home_bases_on_balls',
                  'home_strikeouts',
                  'home_plate_appearances',
                  'home_pitches',
                  'home_strikes',
                  'home_base_out_runs_added',
                  'home_putouts',
                  'home_assists',
                  'home_innings_pitched',
                  'home_home_runs',
                  'home_strikes_by_contact',
                  'home_strikes_swinging',
                  'home_strikes_looking',
                  'home_grounded_balls',
                  'home_fly_balls',
                  'home_line_drives',
                  'home_game_score',
                  'home_base_out_runs_saved']

# Drop any columns that are null
allBoxes.dropna(axis=1, inplace=True)

# Keep only certain columns and reorder
allBoxes = allBoxes.filter(items=keeping_labels)
allBoxes = allBoxes[keeping_labels]
allBoxes.rename(columns={'away_home_runs': 'away_homeruns', 'home_home_runs': 'home_homeruns'}, inplace=True)

print(f'There are {allBoxes.shape[0]} examples')
allBoxes
# Out:
# There are 15475 examples
#                                           date away home winner  away_at_bats  \
# game_id
# COL/COL201504100        Friday, April 10, 2015  CHC  COL   Home            30
# TEX/TEX201504100        Friday, April 10, 2015  HOU  TEX   Away            34
# CHA/CHA201504100        Friday, April 10, 2015  MIN  CHW   Away            36
# BAL/BAL201504100        Friday, April 10, 2015  TOR  BAL   Away            39
# CLE/CLE201504100        Friday, April 10, 2015  DET  CLE   Away            43
# ...                                        ...  ...  ...    ...           ...
# PIT/PIT202009090  Wednesday, September 9, 2020  CHW  PIT   Away            37
# TEX/TEX202009090  Wednesday, September 9, 2020  LAA  TEX   Home            35
# ATL/ATL202009090  Wednesday, September 9, 2020  MIA  ATL   Home            38
# NYN/NYN202009090  Wednesday, September 9, 2020  BAL  NYM   Home            40
# CHN/CHN202009090  Wednesday, September 9, 2020  CIN  CHC   Away            30
#
#                   away_runs  away_hits  away_rbi  away_earned_runs  \
# game_id
# COL/COL201504100          1          5         1               1.0
# TEX/TEX201504100          5         10         5               5.0
# CHA/CHA201504100          6         10         5               5.0
# BAL/BAL201504100         12         16        12              12.0
# CLE/CLE201504100          8         18         7               6.0
# ...                     ...        ...       ...               ...
# PIT/PIT202009090          8         11         8               8.0
# TEX/TEX202009090          3          7         2               2.0
# ATL/ATL202009090          9         13         9               9.0
# NYN/NYN202009090          6         14         6               6.0
# CHN/CHN202009090          3          4         3               3.0
#
#                   away_bases_on_balls  away_strikeouts  \
# game_id
# COL/COL201504100                    4                7
# TEX/TEX201504100                    2                7
# CHA/CHA201504100                    9                9
# BAL/BAL201504100                    3                6
# CLE/CLE201504100                    3                9
# ...                               ...              ...
# PIT/PIT202009090                    3               10
# TEX/TEX202009090                    4                8
# ATL/ATL202009090                    4                7
# NYN/NYN202009090                    3                7
# CHN/CHN202009090                    3               14
#
#                   away_plate_appearances  away_pitches  away_strikes  \
# game_id
# COL/COL201504100                      37           150            76
# TEX/TEX201504100                      37           119            79
# CHA/CHA201504100                      46           112           112
# BAL/BAL201504100                      47           130           103
# CLE/CLE201504100                      47           139           117
# ...                                  ...           ...           ...
# PIT/PIT202009090                      41           137           106
# TEX/TEX202009090                      39           155           109
# ATL/ATL202009090                      43           240           121
# NYN/NYN202009090                      46           137            96
# CHN/CHN202009090                      33           123            92
#
#                   away_base_out_runs_added  away_putouts  away_assists  \
# game_id
# COL/COL201504100                      -3.9            24             8
# TEX/TEX201504100                       0.4            27            15
# CHA/CHA201504100                       1.8            27            10
# BAL/BAL201504100                       7.5            27            13
# CLE/CLE201504100                       3.3            27             7
# ...                                    ...           ...           ...
# PIT/PIT202009090                       3.4            27            10
# TEX/TEX202009090                      -2.5            24             8
# ATL/ATL202009090                       4.0            24             7
# NYN/NYN202009090                       1.6            24            11
# CHN/CHN202009090                      -1.9            27             6
#
#                   away_innings_pitched  away_homeruns  \
# game_id
# COL/COL201504100                   8.0              1
# TEX/TEX201504100                   9.0              0
# CHA/CHA201504100                   9.0              0
# BAL/BAL201504100                   9.0              2
# CLE/CLE201504100                   9.0              0
# ...                                ...            ...
# PIT/PIT202009090                   9.0              0
# TEX/TEX202009090                   8.0              0
# ATL/ATL202009090                   8.0              7
# NYN/NYN202009090                   8.0              4
# CHN/CHN202009090                   9.0              0
#
#                   away_strikes_by_contact  away_strikes_swinging  \
# game_id
# COL/COL201504100                       37                     18
# TEX/TEX201504100                       45                     15
# CHA/CHA201504100                       60                     26
# BAL/BAL201504100                       63                     14
# CLE/CLE201504100                       67                     13
# ...                                   ...                    ...
# PIT/PIT202009090                       61                     23
# TEX/TEX202009090                       64                     13
# ATL/ATL202009090                       67                     26
# NYN/NYN202009090                       55                     21
# CHN/CHN202009090                       50                     18
#
#                   away_strikes_looking  away_grounded_balls  away_fly_balls  \
# game_id
# COL/COL201504100                    21                   11              13
# TEX/TEX201504100                    19                   14              14
# CHA/CHA201504100                    26                   13              14
# BAL/BAL201504100                    26                   15              22
# CLE/CLE201504100                    37                   13              22
# ...                                ...                  ...             ...
# PIT/PIT202009090                    22                   14              14
# TEX/TEX202009090                    32                   13              14
# ATL/ATL202009090                    28                    9              23
# NYN/NYN202009090                    20                   13              20
# CHN/CHN202009090                    25                   10               6
#
#                   away_line_drives  away_game_score  away_base_out_runs_saved  \
# game_id
# COL/COL201504100                 7               41                      -0.6
# TEX/TEX201504100                 7               60                       3.6
# CHA/CHA201504100                 7               80                       4.2
# BAL/BAL201504100                10               47                      -0.5
# CLE/CLE201504100                11               43                       0.7
# ...                            ...              ...                       ...
# PIT/PIT202009090                11               68                       3.6
# TEX/TEX202009090                 9               35                      -2.1
# ATL/ATL202009090                 9               17                     -24.6
# NYN/NYN202009090                13               37                      -3.1
# CHN/CHN202009090                 5               83                       4.9
#
#                   home_at_bats  home_runs  home_hits  home_rbi  \
# game_id
# COL/COL201504100            34          5         11         5
# TEX/TEX201504100            32          1          6         1
# CHA/CHA201504100            28          0          3         0
# BAL/BAL201504100            36          5         13         4
# CLE/CLE201504100            34          4         10         4
# ...                        ...        ...        ...       ...
# PIT/PIT202009090            31          1          4         1
# TEX/TEX202009090            32          7          9         6
# ATL/ATL202009090            47         29         23        28
# NYN/NYN202009090            33          7         10         7
# CHN/CHN202009090            30          0          3         0
#
#                   home_earned_runs  home_bases_on_balls  home_strikeouts  \
# game_id
# COL/COL201504100              5.62                    3                7
# TEX/TEX201504100              1.00                    2                8
# CHA/CHA201504100              0.00                    2                7
# BAL/BAL201504100              5.00                    2                2
# CLE/CLE201504100              4.00                    3                7
# ...                            ...                  ...              ...
# PIT/PIT202009090              0.00                    5                5
# TEX/TEX202009090              7.88                    3               10
# ATL/ATL202009090             30.38                    9                9
# NYN/NYN202009090              7.88                    2                8
# CHN/CHN202009090              0.00                    0               10
#
#                   home_plate_appearances  home_pitches  home_strikes  \
# game_id
# COL/COL201504100                      37           140            92
# TEX/TEX201504100                      34           125            82
# CHA/CHA201504100                      30           190            74
# BAL/BAL201504100                      38           162            79
# CLE/CLE201504100                      37           178            86
# ...                                  ...           ...           ...
# PIT/PIT202009090                      37           163            85
# TEX/TEX202009090                      37           163            97
# ATL/ATL202009090                      58           197           141
# NYN/NYN202009090                      36           164            93
# CHN/CHN202009090                      31           140            84
#
#                   home_base_out_runs_added  home_putouts  home_assists  \
# game_id
# COL/COL201504100                       0.6            27            12
# TEX/TEX201504100                      -3.6            27            10
# CHA/CHA201504100                      -4.2            27             9
# BAL/BAL201504100                       0.5            27            10
# CLE/CLE201504100                      -0.7            27             9
# ...                                    ...           ...           ...
# PIT/PIT202009090                      -3.6            27             9
# TEX/TEX202009090                       2.1            27             9
# ATL/ATL202009090                      24.6            27             8
# NYN/NYN202009090                       3.1            27             9
# CHN/CHN202009090                      -4.9            27             9
#
#                   home_innings_pitched  home_homeruns  \
# game_id
# COL/COL201504100                   9.0              0
# TEX/TEX201504100                   9.0              2
# CHA/CHA201504100                   9.0              1
# BAL/BAL201504100                   9.0              0
# CLE/CLE201504100                   9.0              1
# ...                                ...            ...
# PIT/PIT202009090                   9.0              2
# TEX/TEX202009090                   9.0              1
# ATL/ATL202009090                   9.0              2
# NYN/NYN202009090                   9.0              1
# CHN/CHN202009090                   9.0              1
#
#                   home_strikes_by_contact  home_strikes_swinging  \
# game_id
# COL/COL201504100                       56                     13
# TEX/TEX201504100                       41                     16
# CHA/CHA201504100                       43                     12
# BAL/BAL201504100                       51                      9
# CLE/CLE201504100                       50                      5
# ...                                   ...                    ...
# PIT/PIT202009090                       45                     12
# TEX/TEX202009090                       52                     17
# ATL/ATL202009090                       83                     26
# NYN/NYN202009090                       55                     16
# CHN/CHN202009090                       46                     15
#
#                   home_strikes_looking  home_grounded_balls  home_fly_balls  \
# game_id
# COL/COL201504100                    23                    9              18
# TEX/TEX201504100                    25                   15               9
# CHA/CHA201504100                    19                   10              11
# BAL/BAL201504100                    19                   13              21
# CLE/CLE201504100                    31                    8              19
# ...                                ...                  ...             ...
# PIT/PIT202009090                    28                   13              13
# TEX/TEX202009090                    28                   13              10
# ATL/ATL202009090                    32                   14              25
# NYN/NYN202009090                    22                   13              12
# CHN/CHN202009090                    23                    7              13
#
#                   home_line_drives  home_game_score  home_base_out_runs_saved
# game_id
# COL/COL201504100                10               51                       3.9
# TEX/TEX201504100                 7               45                      -0.4
# CHA/CHA201504100                 4               48                      -1.8
# BAL/BAL201504100                12               13                      -7.5
# CLE/CLE201504100                 9               20                      -3.3
# ...                            ...              ...                       ...
# PIT/PIT202009090                 6               29                      -3.4
# TEX/TEX202009090                 3               47                       2.5
# ATL/ATL202009090                16               14                      -4.0
# NYN/NYN202009090                 6               25                      -1.6
# CHN/CHN202009090                 4               62                       1.9
#
# [15475 rows x 50 columns]

# %%
new_labels = ['date',
                  'away',
                  'home',
                  'winner',
                  'at_bats',
                  'runs',
                  'hits',
                  'rbi',
                  'earned_runs',
                  'bases_on_balls',
                  'strikeouts',
                  'plate_appearances',
                  'pitches',
                  'strikes',
                  'base_out_runs_added',
                  'putouts',
                  'assists',
                  'innings_pitched',
                  'homeruns',
                  'strikes_by_contact',
                  'strikes_swinging',
                  'strikes_looking',
                  'grounded_balls',
                  'fly_balls',
                  'line_drives',
                  'game_score',
                  'base_out_runs_saved']

def generateTeamStats(dataframe, teams=TEAMS):
    """Returns a dictionary, where each key is a team and each
    value is a dataframe for their stats"""
    
    team_stats_dict = dict()
    
    for team in tqdm(teams):
        away_games = dataframe.loc[(dataframe["away"] == team)].copy()
        home_games = dataframe.loc[(dataframe["home"] == team)].copy()        
        
        home_games.drop(home_games.filter(regex="away_").columns, axis=1, inplace=True)
        home_games.columns = new_labels
        
        away_games.drop(away_games.filter(regex="home_").columns, axis=1, inplace=True)
        away_games.columns = new_labels
        
        # Shape for both must match same columns
        assert away_games.shape[1] == home_games.shape[1]
        
        # Join the home games and away games, sort by date
        team_stats = pd.concat([home_games, away_games])
        team_stats.drop_duplicates(inplace=True)
        team_stats.dropna(inplace=True)
        team_stats.sort_values(by=["date"], inplace=True)
        team_stats_dict[team] = team_stats   
    
    return team_stats_dict

# %%
team_stats = generateTeamStats(allBoxes)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
team_stats['NYY']
# Out:
#                                           date away home winner  at_bats  \
# game_id
# NYA/NYA201504100        Friday, April 10, 2015  BOS  NYY   Away       67
# NYA/NYA201404110        Friday, April 11, 2014  BOS  NYY   Away       33
# NYA/NYA201904120        Friday, April 12, 2019  CHW  NYY   Away       24
# DET/DET201804130        Friday, April 13, 2018  NYY  DET   Away       38
# NYA/NYA201704140        Friday, April 14, 2017  STL  NYY   Home       32
# ...                                        ...  ...  ...    ...      ...
# NYA/NYA201909040  Wednesday, September 4, 2019  TEX  NYY   Home       30
# OAK/OAK201809050  Wednesday, September 5, 2018  NYY  OAK   Home       31
# NYA/NYA201609070  Wednesday, September 7, 2016  TOR  NYY   Home       33
# NYA/NYA201509090  Wednesday, September 9, 2015  BAL  NYY   Away       31
# TOR/TOR202009090  Wednesday, September 9, 2020  NYY  TOR   Away       35
#
#                   runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# game_id
# NYA/NYA201504100     5    14    5         2.37               6          13
# NYA/NYA201404110     2     7    2         2.00               2           9
# NYA/NYA201904120     6     7    6         6.00               4           7
# DET/DET201804130     8    11    7         7.00               4           8
# NYA/NYA201704140     4     9    3         3.38               4          10
# ...                ...   ...  ...          ...             ...         ...
# NYA/NYA201909040     4     6    4         4.50               5          10
# OAK/OAK201809050     2     5    2         2.00               3           7
# NYA/NYA201609070     2     9    2         2.25               2          12
# NYA/NYA201509090     3     4    3         3.00               0           9
# TOR/TOR202009090     7     7    7         5.00               7           6
#
#                   plate_appearances  pitches  strikes  base_out_runs_added  \
# game_id
# NYA/NYA201504100                 75      332      176                 -4.3
# NYA/NYA201404110                 35      149       92                 -2.2
# NYA/NYA201904120                 30      137       77                  2.8
# DET/DET201804130                 44      161       90                  3.3
# NYA/NYA201704140                 36      153       78                 -0.4
# ...                             ...      ...      ...                  ...
# NYA/NYA201909040                 35      133       98                 -0.3
# OAK/OAK201809050                 34      127       94                 -2.5
# NYA/NYA201609070                 35      143       84                 -2.2
# NYA/NYA201509090                 32      162       82                 -1.4
# TOR/TOR202009090                 42      114       95                  2.2
#
#                   putouts  assists  innings_pitched  homeruns  \
# game_id
# NYA/NYA201504100       57       19             19.0         1
# NYA/NYA201404110       27        8              9.0         2
# NYA/NYA201904120       19        3              6.1         4
# DET/DET201804130       27        5              9.0         2
# NYA/NYA201704140       27       10              9.0         1
# ...                   ...      ...              ...       ...
# NYA/NYA201909040       27        6              9.0         1
# OAK/OAK201809050       24        6              8.0         0
# NYA/NYA201609070       27       16              9.0         0
# NYA/NYA201509090       27       12              9.0         1
# TOR/TOR202009090       27        7              9.0         1
#
#                   strikes_by_contact  strikes_swinging  strikes_looking  \
# game_id
# NYA/NYA201504100                  97                16               63
# NYA/NYA201404110                  53                10               29
# NYA/NYA201904120                  46                12               19
# DET/DET201804130                  48                12               30
# NYA/NYA201704140                  43                18               17
# ...                              ...               ...              ...
# NYA/NYA201909040                  56                19               23
# OAK/OAK201809050                  51                12               31
# NYA/NYA201609070                  40                23               21
# NYA/NYA201509090                  44                13               25
# TOR/TOR202009090                  50                12               33
#
#                   grounded_balls  fly_balls  line_drives  game_score  \
# game_id
# NYA/NYA201504100              30         25            7          40
# NYA/NYA201404110              14         10            4          56
# NYA/NYA201904120               5         13            8          23
# DET/DET201804130              17         14            6          54
# NYA/NYA201704140               7         15            6          54
# ...                          ...        ...          ...         ...
# NYA/NYA201909040               9         11            4          55
# OAK/OAK201809050              12         12            3          26
# NYA/NYA201609070               8         13            7          59
# NYA/NYA201509090               9         13            4          50
# TOR/TOR202009090              17         12            2          65
#
#                   base_out_runs_saved
# game_id
# NYA/NYA201504100                  3.3
# NYA/NYA201404110                  0.2
# NYA/NYA201904120                 -5.5
# DET/DET201804130                 -1.3
# NYA/NYA201704140                  1.9
# ...                               ...
# NYA/NYA201909040                  3.9
# OAK/OAK201809050                 -4.0
# NYA/NYA201609070                  4.7
# NYA/NYA201509090                 -0.6
# TOR/TOR202009090                  2.8
#
# [1032 rows x 27 columns]

# %%
def computeMA(span, team_stats):
    """Compute moving averages for each team"""
    
    team_ma = dict()
    
    for team, dataframe in tqdm(team_stats.items(), unit='teams'):
        
        df = dataframe.copy()

        # Compute the moving averages for the appropriate columns
        for col in df.columns:
            if col in {'date', 'away', 'home', 'winner'}:
                continue

            # Exponential moving average
            df[f"{col} EMA"] = df.loc[:, col].ewm(span=span, adjust=False).mean()
            df[f"{col} EMA"] = df[f"{col} EMA"].shift(1)
        
        df["batting_average EMA"] = df["hits EMA"] / df["at_bats EMA"]
        df["era EMA"] = (df["earned_runs EMA"] * 9) / df["innings_pitched EMA"]
        
        # Drop any rows with NULL values and save the dataframe
        df.dropna(inplace=True)
        df.drop_duplicates(inplace=True)
        
        team_ma[team] = df
    
    return team_ma

# %%
team_ma = computeMA(span=5, team_stats=team_stats)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
team_ma['NYY']
# Out:
#                                           date away home winner  at_bats  \
# game_id
# NYA/NYA201404110        Friday, April 11, 2014  BOS  NYY   Away       33
# NYA/NYA201904120        Friday, April 12, 2019  CHW  NYY   Away       24
# DET/DET201804130        Friday, April 13, 2018  NYY  DET   Away       38
# NYA/NYA201704140        Friday, April 14, 2017  STL  NYY   Home       32
# NYA/NYA201604150        Friday, April 15, 2016  SEA  NYY   Away       33
# ...                                        ...  ...  ...    ...      ...
# NYA/NYA201909040  Wednesday, September 4, 2019  TEX  NYY   Home       30
# OAK/OAK201809050  Wednesday, September 5, 2018  NYY  OAK   Home       31
# NYA/NYA201609070  Wednesday, September 7, 2016  TOR  NYY   Home       33
# NYA/NYA201509090  Wednesday, September 9, 2015  BAL  NYY   Away       31
# TOR/TOR202009090  Wednesday, September 9, 2020  NYY  TOR   Away       35
#
#                   runs  hits  rbi  earned_runs  bases_on_balls  strikeouts  \
# game_id
# NYA/NYA201404110     2     7    2         2.00               2           9
# NYA/NYA201904120     6     7    6         6.00               4           7
# DET/DET201804130     8    11    7         7.00               4           8
# NYA/NYA201704140     4     9    3         3.38               4          10
# NYA/NYA201604150     1     6    1         1.00               7          10
# ...                ...   ...  ...          ...             ...         ...
# NYA/NYA201909040     4     6    4         4.50               5          10
# OAK/OAK201809050     2     5    2         2.00               3           7
# NYA/NYA201609070     2     9    2         2.25               2          12
# NYA/NYA201509090     3     4    3         3.00               0           9
# TOR/TOR202009090     7     7    7         5.00               7           6
#
#                   plate_appearances  pitches  strikes  base_out_runs_added  \
# game_id
# NYA/NYA201404110                 35      149       92                 -2.2
# NYA/NYA201904120                 30      137       77                  2.8
# DET/DET201804130                 44      161       90                  3.3
# NYA/NYA201704140                 36      153       78                 -0.4
# NYA/NYA201604150                 40      152       93                 -3.7
# ...                             ...      ...      ...                  ...
# NYA/NYA201909040                 35      133       98                 -0.3
# OAK/OAK201809050                 34      127       94                 -2.5
# NYA/NYA201609070                 35      143       84                 -2.2
# NYA/NYA201509090                 32      162       82                 -1.4
# TOR/TOR202009090                 42      114       95                  2.2
#
#                   putouts  assists  innings_pitched  homeruns  \
# game_id
# NYA/NYA201404110       27        8              9.0         2
# NYA/NYA201904120       19        3              6.1         4
# DET/DET201804130       27        5              9.0         2
# NYA/NYA201704140       27       10              9.0         1
# NYA/NYA201604150       27        9              9.0         1
# ...                   ...      ...              ...       ...
# NYA/NYA201909040       27        6              9.0         1
# OAK/OAK201809050       24        6              8.0         0
# NYA/NYA201609070       27       16              9.0         0
# NYA/NYA201509090       27       12              9.0         1
# TOR/TOR202009090       27        7              9.0         1
#
#                   strikes_by_contact  strikes_swinging  strikes_looking  \
# game_id
# NYA/NYA201404110                  53                10               29
# NYA/NYA201904120                  46                12               19
# DET/DET201804130                  48                12               30
# NYA/NYA201704140                  43                18               17
# NYA/NYA201604150                  42                15               36
# ...                              ...               ...              ...
# NYA/NYA201909040                  56                19               23
# OAK/OAK201809050                  51                12               31
# NYA/NYA201609070                  40                23               21
# NYA/NYA201509090                  44                13               25
# TOR/TOR202009090                  50                12               33
#
#                   grounded_balls  fly_balls  line_drives  game_score  \
# game_id
# NYA/NYA201404110              14         10            4          56
# NYA/NYA201904120               5         13            8          23
# DET/DET201804130              17         14            6          54
# NYA/NYA201704140               7         15            6          54
# NYA/NYA201604150               9         14            3          38
# ...                          ...        ...          ...         ...
# NYA/NYA201909040               9         11            4          55
# OAK/OAK201809050              12         12            3          26
# NYA/NYA201609070               8         13            7          59
# NYA/NYA201509090               9         13            4          50
# TOR/TOR202009090              17         12            2          65
#
#                   base_out_runs_saved  at_bats EMA  runs EMA   hits EMA  \
# game_id
# NYA/NYA201404110                  0.2    67.000000  5.000000  14.000000
# NYA/NYA201904120                 -5.5    55.666667  4.000000  11.666667
# DET/DET201804130                 -1.3    45.111111  4.666667  10.111111
# NYA/NYA201704140                  1.9    42.740741  5.777778  10.407407
# NYA/NYA201604150                 -2.3    39.160494  5.185185   9.938272
# ...                               ...          ...       ...        ...
# NYA/NYA201909040                  3.9    35.055519  4.969086   9.237461
# OAK/OAK201809050                 -4.0    33.370346  4.646057   8.158307
# NYA/NYA201609070                  4.7    32.580230  3.764038   7.105538
# NYA/NYA201509090                 -0.6    32.720154  3.176026   7.737025
# TOR/TOR202009090                  2.8    32.146769  3.117350   6.491350
#
#                    rbi EMA  earned_runs EMA  bases_on_balls EMA  \
# game_id
# NYA/NYA201404110  5.000000         2.370000            6.000000
# NYA/NYA201904120  4.000000         2.246667            4.666667
# DET/DET201804130  4.666667         3.497778            4.444444
# NYA/NYA201704140  5.444444         4.665185            4.296296
# NYA/NYA201604150  4.629630         4.236790            4.197531
# ...                    ...              ...                 ...
# NYA/NYA201909040  4.940335         4.893283            6.485995
# OAK/OAK201809050  4.626890         4.762188            5.990664
# NYA/NYA201609070  3.751260         3.841459            4.993776
# NYA/NYA201509090  3.167507         3.310973            3.995850
# TOR/TOR202009090  3.111671         3.207315            2.663900
#
#                   strikeouts EMA  plate_appearances EMA  pitches EMA  \
# game_id
# NYA/NYA201404110       13.000000              75.000000   332.000000
# NYA/NYA201904120       11.666667              61.666667   271.000000
# DET/DET201804130       10.111111              51.111111   226.333333
# NYA/NYA201704140        9.407407              48.740741   204.555556
# NYA/NYA201604150        9.604938              44.493827   187.370370
# ...                          ...                    ...          ...
# NYA/NYA201909040        6.716166              41.851855   161.304227
# OAK/OAK201809050        7.810777              39.567903   151.869485
# NYA/NYA201609070        7.540518              37.711936   143.579656
# NYA/NYA201509090        9.027012              36.807957   143.386438
# TOR/TOR202009090        9.018008              35.205305   149.590958
#
#                   strikes EMA  base_out_runs_added EMA  putouts EMA  \
# game_id
# NYA/NYA201404110   176.000000                -4.300000    57.000000
# NYA/NYA201904120   148.000000                -3.600000    47.000000
# DET/DET201804130   124.333333                -1.466667    37.666667
# NYA/NYA201704140   112.888889                 0.122222    34.111111
# NYA/NYA201604150   101.259259                -0.051852    31.740741
# ...                       ...                      ...          ...
# NYA/NYA201909040   101.666179                 0.332742    28.572878
# OAK/OAK201809050   100.444119                 0.121828    28.048585
# NYA/NYA201609070    98.296079                -0.752115    26.699057
# NYA/NYA201509090    93.530720                -1.234743    26.799371
# TOR/TOR202009090    89.687146                -1.289829    26.866248
#
#                   assists EMA  innings_pitched EMA  homeruns EMA  \
# game_id
# NYA/NYA201404110    19.000000            19.000000      1.000000
# NYA/NYA201904120    15.333333            15.666667      1.333333
# DET/DET201804130    11.222222            12.477778      2.222222
# NYA/NYA201704140     9.148148            11.318519      2.148148
# NYA/NYA201604150     9.432099            10.545679      1.765432
# ...                       ...                  ...           ...
# NYA/NYA201909040     8.796664             9.524293      1.363653
# OAK/OAK201809050     7.864443             9.349528      1.242435
# NYA/NYA201609070     7.242962             8.899686      0.828290
# NYA/NYA201509090    10.161975             8.933124      0.552193
# TOR/TOR202009090    10.774650             8.955416      0.701462
#
#                   strikes_by_contact EMA  strikes_swinging EMA  \
# game_id
# NYA/NYA201404110               97.000000             16.000000
# NYA/NYA201904120               82.333333             14.000000
# DET/DET201804130               70.222222             13.333333
# NYA/NYA201704140               62.814815             12.888889
# NYA/NYA201604150               56.209877             14.592593
# ...                                  ...                   ...
# NYA/NYA201909040               59.885060             13.073873
# OAK/OAK201809050               58.590040             15.049249
# NYA/NYA201609070               56.060027             14.032832
# NYA/NYA201509090               50.706685             17.021888
# TOR/TOR202009090               48.471123             15.681259
#
#                   strikes_looking EMA  grounded_balls EMA  fly_balls EMA  \
# game_id
# NYA/NYA201404110            63.000000           30.000000      25.000000
# NYA/NYA201904120            51.666667           24.666667      20.000000
# DET/DET201804130            40.777778           18.111111      17.666667
# NYA/NYA201704140            37.185185           17.740741      16.444444
# NYA/NYA201604150            30.456790           14.160494      15.962963
# ...                               ...                 ...            ...
# NYA/NYA201909040            28.929487           12.204387      16.372799
# OAK/OAK201809050            26.952992           11.136258      14.581866
# NYA/NYA201609070            28.301994           11.424172      13.721244
# NYA/NYA201509090            25.867996           10.282781      13.480829
# TOR/TOR202009090            25.578664            9.855188      13.320553
#
#                   line_drives EMA  game_score EMA  base_out_runs_saved EMA  \
# game_id
# NYA/NYA201404110         7.000000       40.000000                 3.300000
# NYA/NYA201904120         6.000000       45.333333                 2.266667
# DET/DET201804130         6.666667       37.888889                -0.322222
# NYA/NYA201704140         6.444444       43.259259                -0.648148
# NYA/NYA201604150         6.296296       46.839506                 0.201235
# ...                           ...             ...                      ...
# NYA/NYA201909040         5.699875       55.218911                -0.422413
# OAK/OAK201809050         5.133250       55.145941                 1.018392
# NYA/NYA201609070         4.422167       45.430627                -0.654406
# NYA/NYA201509090         5.281444       49.953751                 1.130396
# TOR/TOR202009090         4.854296       49.969168                 0.553598
#
#                   batting_average EMA   era EMA
# game_id
# NYA/NYA201404110             0.208955  1.122632
# NYA/NYA201904120             0.209581  1.290638
# DET/DET201804130             0.224138  2.522885
# NYA/NYA201704140             0.243501  3.709555
# NYA/NYA201604150             0.253783  3.615804
# ...                               ...       ...
# NYA/NYA201909040             0.263509  4.623917
# OAK/OAK201809050             0.244478  4.584156
# NYA/NYA201609070             0.218094  3.884759
# NYA/NYA201509090             0.236461  3.335760
# TOR/TOR202009090             0.201929  3.223283
#
# [1031 rows x 52 columns]

# %%
def mergeMAWithSchedule(schedule, team_ma_dict):
    
    schedule = schedule.filter(items=['date', 'away', 'home', 'winner'])
    
    aways = []
    homes = []
    
    for team, df in tqdm(team_ma_dict.items()):
        
        # Merge in visiting team stats
        away = schedule.join(df.loc[df["away"] == team].drop(columns=['date', 'away', 'home', 'winner']))
        away.dropna(inplace=True)
        away.drop(away.loc[:, 'at_bats':'base_out_runs_saved'].columns, axis=1, inplace=True)
        away_cols = {col: f'away_{col}' for col in away.columns[4:]}
        away.rename(columns=away_cols, inplace=True) 
        
        # Merge in home team stats
        home = schedule.join(df.loc[df["home"] == team].drop(columns=['date', 'away', 'home', 'winner']))
        home.dropna(inplace=True)
        home.drop(home.loc[:, 'at_bats':'base_out_runs_saved'].columns, axis=1, inplace=True)
        home_cols = {col: f'home_{col}' for col in home.columns[4:]}
        home.rename(columns=home_cols, inplace=True) 
        
        homes.append(home)
        aways.append(away)
        
        assert home.shape[1] == away.shape[1]
        

    return pd.merge(pd.concat(homes),
                    pd.concat(aways).drop(columns=['date', 'away', 'home', 'winner']),
                    left_index=True,
                    right_index=True)

# %%
mergeMAWithSchedule(allBoxes, team_ma)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
#                                            date away home winner  \
# game_id
# WAS/WAS201904120         Friday, April 12, 2019  PIT  WSN   Away
# WAS/WAS201804130         Friday, April 13, 2018  COL  WSN   Away
# WAS/WAS201704140         Friday, April 14, 2017  PHI  WSN   Home
# WAS/WAS201504170         Friday, April 17, 2015  PHI  WSN   Home
# WAS/WAS201404180         Friday, April 18, 2014  STL  WSN   Home
# ...                                         ...  ...  ...    ...
# SLN/SLN201709270  Wednesday, September 27, 2017  CHC  STL   Away
# SLN/SLN201609280  Wednesday, September 28, 2016  CIN  STL   Away
# SLN/SLN201409030   Wednesday, September 3, 2014  PIT  STL   Home
# SLN/SLN201909040   Wednesday, September 4, 2019  SFG  STL   Away
# SLN/SLN201509090   Wednesday, September 9, 2015  CHC  STL   Home
#
#                   home_at_bats EMA  home_runs EMA  home_hits EMA  \
# game_id
# WAS/WAS201904120         35.000000       2.666667       8.666667
# WAS/WAS201804130         35.333333       2.777778       8.111111
# WAS/WAS201704140         33.555556       2.185185       6.740741
# WAS/WAS201504170         37.024691       4.637860      10.329218
# WAS/WAS201404180         36.349794       5.425240      10.219479
# ...                            ...            ...            ...
# SLN/SLN201709270         31.872484       3.474334       6.537918
# SLN/SLN201609280         31.581656       2.649556       6.025279
# SLN/SLN201409030         31.721104       2.099704       6.350186
# SLN/SLN201909040         32.991438       3.881394       7.955611
# SLN/SLN201509090         33.924235       4.260522       9.188763
#
#                   home_rbi EMA  home_earned_runs EMA  home_bases_on_balls EMA  \
# game_id
# WAS/WAS201904120      2.666667              1.566667                 2.000000
# WAS/WAS201804130      2.777778              1.944444                 2.333333
# WAS/WAS201704140      2.185185              1.629630                 2.888889
# WAS/WAS201504170      4.304527              4.057613                 3.172840
# WAS/WAS201404180      4.869684              4.955075                 3.115226
# ...                        ...                   ...                      ...
# SLN/SLN201709270      3.100035              3.408303                 2.840585
# SLN/SLN201609280      2.400023              2.605535                 2.893723
# SLN/SLN201409030      1.600016              2.070357                 2.929149
# SLN/SLN201909040      3.511116              3.878624                 2.645674
# SLN/SLN201509090      4.187381              3.506889                 2.744824
#
#                   home_strikeouts EMA  home_plate_appearances EMA  \
# game_id
# WAS/WAS201904120             8.666667                   37.333333
# WAS/WAS201804130             7.777778                   38.555556
# WAS/WAS201704140             8.518519                   37.370370
# WAS/WAS201504170             9.119342                   40.831276
# WAS/WAS201404180             8.079561                   40.220850
# ...                               ...                         ...
# SLN/SLN201709270             9.739400                   36.186176
# SLN/SLN201609280             8.492933                   35.457451
# SLN/SLN201409030             7.328622                   35.638300
# SLN/SLN201909040             6.245518                   37.300237
# SLN/SLN201509090             7.208991                   37.898812
#
#                   home_pitches EMA  home_strikes EMA  \
# game_id
# WAS/WAS201904120        140.333333         90.333333
# WAS/WAS201804130        149.222222         93.222222
# WAS/WAS201704140        144.814815         96.148148
# WAS/WAS201504170        140.251029        102.176955
# WAS/WAS201404180        132.500686         97.451303
# ...                            ...               ...
# SLN/SLN201709270        155.864936         85.362927
# SLN/SLN201609280        141.576624         85.241951
# SLN/SLN201409030        149.717749         80.494634
# SLN/SLN201909040        141.138592         87.628040
# SLN/SLN201509090        148.977994         98.198131
#
#                   home_base_out_runs_added EMA  home_putouts EMA  \
# game_id
# WAS/WAS201904120                     -1.433333         25.666667
# WAS/WAS201804130                     -1.822222         27.111111
# WAS/WAS201704140                     -2.414815         27.074074
# WAS/WAS201504170                      0.193416         27.699588
# WAS/WAS201404180                      1.195610         27.466392
# ...                                        ...               ...
# SLN/SLN201709270                     -0.959445         25.361290
# SLN/SLN201609280                     -1.839630         25.907526
# SLN/SLN201409030                     -2.359753         26.271684
# SLN/SLN201909040                     -0.236223         25.784203
# SLN/SLN201509090                     -0.142958         25.759843
#
#                   home_assists EMA  home_innings_pitched EMA  \
# game_id
# WAS/WAS201904120         14.666667                  8.400000
# WAS/WAS201804130         13.444444                  8.933333
# WAS/WAS201704140         10.962963                  8.955556
# WAS/WAS201504170         10.094650                  9.202469
# WAS/WAS201404180          9.063100                  9.134979
# ...                            ...                       ...
# SLN/SLN201709270          9.845772                  8.449211
# SLN/SLN201609280          9.230515                  8.632807
# SLN/SLN201409030         10.153676                  8.755205
# SLN/SLN201909040         10.786275                  8.594135
# SLN/SLN201509090         10.044202                  8.586496
#
#                   home_homeruns EMA  home_strikes_by_contact EMA  \
# game_id
# WAS/WAS201904120           0.666667                    48.666667
# WAS/WAS201804130           1.111111                    52.777778
# WAS/WAS201704140           1.074074                    55.518519
# WAS/WAS201504170           1.032922                    57.341564
# WAS/WAS201404180           0.688615                    54.561043
# ...                             ...                          ...
# SLN/SLN201709270           0.858718                    43.617068
# SLN/SLN201609280           0.905812                    43.078046
# SLN/SLN201409030           0.603875                    44.052030
# SLN/SLN201909040           0.845592                    51.978379
# SLN/SLN201509090           1.018882                    59.785853
#
#                   home_strikes_swinging EMA  home_strikes_looking EMA  \
# game_id
# WAS/WAS201904120                  19.333333                 23.000000
# WAS/WAS201804130                  17.222222                 23.666667
# WAS/WAS201704140                  17.481481                 23.444444
# WAS/WAS201504170                  19.769547                 25.197531
# WAS/WAS201404180                  16.846365                 26.131687
# ...                                     ...                       ...
# SLN/SLN201709270                  16.217363                 25.529557
# SLN/SLN201609280                  15.478242                 26.686371
# SLN/SLN201409030                  12.652162                 23.790914
# SLN/SLN201909040                  11.230270                 24.419530
# SLN/SLN201509090                  14.675115                 23.737191
#
#                   home_grounded_balls EMA  home_fly_balls EMA  \
# game_id
# WAS/WAS201904120                12.333333           14.333333
# WAS/WAS201804130                10.888889           17.222222
# WAS/WAS201704140                10.592593           15.148148
# WAS/WAS201504170                12.263374           15.954733
# WAS/WAS201404180                13.508916           14.969822
# ...                                   ...                 ...
# SLN/SLN201709270                10.791618           11.984430
# SLN/SLN201609280                10.194412           13.322953
# SLN/SLN201409030                10.796275           13.881969
# SLN/SLN201909040                13.680378           13.779843
# SLN/SLN201509090                11.529457           15.746636
#
#                   home_line_drives EMA  home_game_score EMA  \
# game_id
# WAS/WAS201904120              6.333333            45.333333
# WAS/WAS201804130              7.555556            55.222222
# WAS/WAS201704140              6.703704            57.481481
# WAS/WAS201504170              9.312757            65.325103
# WAS/WAS201404180              7.875171            69.883402
# ...                                ...                  ...
# SLN/SLN201709270              7.704555            46.278743
# SLN/SLN201609280              7.136370            45.852496
# SLN/SLN201409030              7.090913            48.901664
# SLN/SLN201909040              7.434345            51.748641
# SLN/SLN201509090              7.703080            45.123188
#
#                   home_base_out_runs_saved EMA  home_batting_average EMA  \
# game_id
# WAS/WAS201904120                     -1.233333                  0.247619
# WAS/WAS201804130                     -0.955556                  0.229560
# WAS/WAS201704140                      0.229630                  0.200883
# WAS/WAS201504170                      1.990947                  0.278982
# WAS/WAS201404180                      2.093964                  0.281143
# ...                                        ...                       ...
# SLN/SLN201709270                     -1.015426                  0.205127
# SLN/SLN201609280                     -0.810284                  0.190784
# SLN/SLN201409030                      0.259811                  0.200188
# SLN/SLN201909040                     -0.074871                  0.241142
# SLN/SLN201509090                      0.075334                  0.270861
#
#                   home_era EMA  away_at_bats EMA  away_runs EMA  \
# game_id
# WAS/WAS201904120      1.678571         32.000000       4.666667
# WAS/WAS201804130      1.958955         43.555556       4.000000
# WAS/WAS201704140      1.637717         32.481481       4.740741
# WAS/WAS201504170      3.968339         32.658436       2.884774
# WAS/WAS201404180      4.881859         34.086420       6.773663
# ...                        ...               ...            ...
# SLN/SLN201709270      3.630484         33.501098       4.079908
# SLN/SLN201609280      2.716361         32.983020       3.236586
# SLN/SLN201409030      2.128244         33.860350       5.890401
# SLN/SLN201909040      4.061796         30.976109       2.946392
# SLN/SLN201509090      3.675772         32.080083       3.387850
#
#                   away_hits EMA  away_rbi EMA  away_earned_runs EMA  \
# game_id
# WAS/WAS201904120       8.000000      4.666667              4.333333
# WAS/WAS201804130      11.000000      3.444444              3.720000
# WAS/WAS201704140       9.000000      4.592593              5.000000
# WAS/WAS201504170       6.666667      2.818930              2.955556
# WAS/WAS201404180       9.172840      6.707819              6.499671
# ...                         ...           ...                   ...
# SLN/SLN201709270       8.337577      3.996872              3.674166
# SLN/SLN201609280       6.592777      3.235216              3.188611
# SLN/SLN201409030      10.309897      5.444331              6.321962
# SLN/SLN201909040       7.572282      2.932194              3.151349
# SLN/SLN201509090       6.794792      3.190946              3.029398
#
#                   away_bases_on_balls EMA  away_strikeouts EMA  \
# game_id
# WAS/WAS201904120                 2.000000            10.666667
# WAS/WAS201804130                 2.777778            13.333333
# WAS/WAS201704140                 3.888889             8.629630
# WAS/WAS201504170                 3.395062             8.279835
# WAS/WAS201404180                 3.135802             8.839506
# ...                                   ...                  ...
# SLN/SLN201709270                 3.857448             7.016306
# SLN/SLN201609280                 2.780439             7.569478
# SLN/SLN201409030                 2.611901             7.617456
# SLN/SLN201909040                 2.446402             7.577137
# SLN/SLN201509090                 2.912553             8.986780
#
#                   away_plate_appearances EMA  away_pitches EMA  \
# game_id
# WAS/WAS201904120                   38.333333        131.666667
# WAS/WAS201804130                   47.222222        172.222222
# WAS/WAS201704140                   37.629630        137.666667
# WAS/WAS201504170                   36.613169        153.851852
# WAS/WAS201404180                   38.440329        129.037037
# ...                                      ...               ...
# SLN/SLN201709270                   38.703838        147.974153
# SLN/SLN201609280                   36.307062        150.498683
# SLN/SLN201409030                   37.619345        141.446007
# SLN/SLN201909040                   33.731358        130.373307
# SLN/SLN201509090                   35.144532        144.197390
#
#                   away_strikes EMA  away_base_out_runs_added EMA  \
# game_id
# WAS/WAS201904120         94.333333                      0.500000
# WAS/WAS201804130        122.222222                     -1.766667
# WAS/WAS201704140         90.851852                      0.640741
# WAS/WAS201504170         90.934156                     -1.604115
# WAS/WAS201404180         89.193416                      2.637449
# ...                            ...                           ...
# SLN/SLN201709270         90.501062                     -0.375983
# SLN/SLN201609280         89.504881                     -1.291852
# SLN/SLN201409030         93.250475                      1.715959
# SLN/SLN201909040         83.404936                     -1.244214
# SLN/SLN201509090         87.762294                     -1.037735
#
#                   away_putouts EMA  away_assists EMA  \
# game_id
# WAS/WAS201904120         26.000000         11.666667
# WAS/WAS201804130         34.666667         11.666667
# WAS/WAS201704140         27.000000          9.518519
# WAS/WAS201504170         27.000000          9.786008
# WAS/WAS201404180         26.555556          9.098765
# ...                            ...               ...
# SLN/SLN201709270         26.962301         11.543967
# SLN/SLN201609280         26.763660         10.710498
# SLN/SLN201409030         27.082433         11.541484
# SLN/SLN201909040         25.984421          9.532099
# SLN/SLN201509090         25.866106         10.407237
#
#                   away_innings_pitched EMA  away_homeruns EMA  \
# game_id
# WAS/WAS201904120                  8.666667           0.666667
# WAS/WAS201804130                 11.477778           0.222222
# WAS/WAS201704140                  9.000000           0.444444
# WAS/WAS201504170                  9.000000           0.864198
# WAS/WAS201404180                  8.851852           1.279835
# ...                                    ...                ...
# SLN/SLN201709270                  8.987434           0.995711
# SLN/SLN201609280                  8.921220           1.030214
# SLN/SLN201409030                  8.958342           0.799707
# SLN/SLN201909040                  8.632359           1.207933
# SLN/SLN201509090                  8.622035           0.916987
#
#                   away_strikes_by_contact EMA  away_strikes_swinging EMA  \
# game_id
# WAS/WAS201904120                    52.333333                  19.333333
# WAS/WAS201804130                    68.888889                  21.444444
# WAS/WAS201704140                    45.259259                  15.666667
# WAS/WAS201504170                    48.559671                  16.518519
# WAS/WAS201404180                    50.728395                  13.213992
# ...                                       ...                        ...
# SLN/SLN201709270                    50.762169                  18.076645
# SLN/SLN201609280                    51.190428                  16.566250
# SLN/SLN201409030                    53.985930                  14.995077
# SLN/SLN201909040                    49.226898                  15.969191
# SLN/SLN201509090                    49.650461                  15.766717
#
#                   away_strikes_looking EMA  away_grounded_balls EMA  \
# game_id
# WAS/WAS201904120                 22.666667                13.333333
# WAS/WAS201804130                 32.555556                13.222222
# WAS/WAS201704140                 29.925926                11.259259
# WAS/WAS201504170                 25.855967                12.004115
# WAS/WAS201404180                 25.251029                11.218107
# ...                                    ...                      ...
# SLN/SLN201709270                 21.662247                14.266465
# SLN/SLN201609280                 21.748712                 9.862105
# SLN/SLN201409030                 24.269464                13.983415
# SLN/SLN201909040                 19.177455                10.841997
# SLN/SLN201509090                 22.345116                11.005993
#
#                   away_fly_balls EMA  away_line_drives EMA  \
# game_id
# WAS/WAS201904120           11.000000              4.333333
# WAS/WAS201804130           17.888889              9.222222
# WAS/WAS201704140           13.037037              5.333333
# WAS/WAS201504170           12.572016              5.592593
# WAS/WAS201404180           14.827160              6.905350
# ...                              ...                   ...
# SLN/SLN201709270           13.315560              7.046046
# SLN/SLN201609280           16.034506              7.934178
# SLN/SLN201409030           12.726015              7.167146
# SLN/SLN201909040           12.857046              6.817660
# SLN/SLN201509090           12.151528              5.358433
#
#                   away_game_score EMA  away_base_out_runs_saved EMA  \
# game_id
# WAS/WAS201904120            51.666667                      1.333333
# WAS/WAS201804130            46.777778                      2.622222
# WAS/WAS201704140            63.259259                      2.981481
# WAS/WAS201504170            49.115226                      0.058436
# WAS/WAS201404180            58.032922                      1.331687
# ...                               ...                           ...
# SLN/SLN201709270            57.689823                      0.373626
# SLN/SLN201609280            48.199650                      0.284110
# SLN/SLN201409030            48.972720                      0.368803
# SLN/SLN201909040            56.829946                      0.610403
# SLN/SLN201509090            61.216871                      1.929961
#
#                   away_batting_average EMA  away_era EMA
# game_id
# WAS/WAS201904120                  0.250000      4.500000
# WAS/WAS201804130                  0.252551      2.916941
# WAS/WAS201704140                  0.277081      5.000000
# WAS/WAS201504170                  0.204133      2.955556
# WAS/WAS201404180                  0.269105      6.608452
# ...                                    ...           ...
# SLN/SLN201709270                  0.248875      3.679303
# SLN/SLN201609280                  0.199884      3.216768
# SLN/SLN201409030                  0.304483      6.351360
# SLN/SLN201909040                  0.244456      3.285561
# SLN/SLN201509090                  0.211807      3.162198
#
# [15460 rows x 54 columns]

# %% [markdown]
# # Training  a Random Forest Classifier

# %%
data = mergeMAWithSchedule(allBoxes, computeMA(14, generateTeamStats(allBoxes)))

data['target'] = np.where(data['winner'] == 'Home', 1, 0)

data.drop(columns=['date', 'away', 'home', 'winner'], inplace=True)
data.reset_index(drop=True, inplace=True)

data.head()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
#    home_at_bats EMA  home_runs EMA  home_hits EMA  home_rbi EMA  \
# 0         33.200000       1.666667       7.066667      1.666667
# 1         33.573333       1.844444       7.057778      1.844444
# 2         33.096889       1.731852       6.650074      1.731852
# 3         34.637219       2.847480       8.168278      2.714147
# 4         34.685590       3.401149       8.412507      3.152260
#
#    home_earned_runs EMA  home_bases_on_balls EMA  home_strikeouts EMA  \
# 0              1.226667                 1.400000             8.866667
# 1              1.423111                 1.613333             8.484444
# 2              1.366696                 1.931556             8.686519
# 3              2.439874                 2.313035             8.897874
# 4              3.014558                 2.404630             8.511491
#
#    home_plate_appearances EMA  home_pitches EMA  home_strikes EMA  \
# 0                   34.733333        129.333333         88.933333
# 1                   35.568889        134.355556         90.275556
# 2                   35.493037        134.574815         91.838815
# 3                   37.414770        135.302861         95.452265
# 4                   37.626134        132.862479         94.458630
#
#    home_base_out_runs_added EMA  home_putouts EMA  home_assists EMA  \
# 0                     -2.373333         24.666667         16.066667
# 1                     -2.403556         25.377778         15.391111
# 2                     -2.563081         25.594074         14.138963
# 3                     -1.450492         26.290660         13.055488
# 4                     -0.830427         26.385239         12.248089
#
#    home_innings_pitched EMA  home_homeruns EMA  home_strikes_by_contact EMA  \
# 0                  8.160000           0.266667                    46.466667
# 1                  8.405333           0.497778                    48.404444
# 2                  8.484622           0.564741                    50.083852
# 3                  8.728450           0.673072                    52.045204
# 4                  8.764656           0.583329                    51.639177
#
#    home_strikes_swinging EMA  home_strikes_looking EMA  \
# 0                  20.933333                 21.800000
# 1                  19.875556                 22.226667
# 2                  19.625481                 22.329778
# 3                  20.100917                 23.456589
# 4                  18.887462                 24.062377
#
#    home_grounded_balls EMA  home_fly_balls EMA  home_line_drives EMA  \
# 0                11.533333           12.933333              5.533333
# 1                11.062222           14.275556              6.128889
# 2                10.920593           13.838815              5.978370
# 3                11.651467           14.350043              7.183754
# 4                12.231272           14.170037              6.892587
#
#    home_game_score EMA  home_base_out_runs_saved EMA  \
# 0            48.733333                     -0.733333
# 1            52.235556                     -0.688889
# 2            53.537481                     -0.250370
# 3            57.857042                      0.658166
# 4            60.676103                      0.877077
#
#    home_batting_average EMA  home_era EMA  away_at_bats EMA  away_runs EMA  \
# 0                  0.212851      1.352941         32.600000       5.466667
# 1                  0.210220      1.523794         37.848889       4.600000
# 2                  0.200927      1.449713         29.702815       4.511407
# 3                  0.235824      2.515781         30.505670       3.753013
# 4                  0.242536      3.095503         35.286479       5.333647
#
#    away_hits EMA  away_rbi EMA  away_earned_runs EMA  away_bases_on_balls EMA  \
# 0       9.200000      5.466667              5.333333                 2.000000
# 1      11.000000      4.351111              4.816800                 2.884444
# 2       8.109333      4.411259              4.912000                 4.051556
# 3       7.317677      3.677790              4.030791                 3.789835
# 4       9.580792      5.258424              5.183830                 3.221242
#
#    away_strikeouts EMA  away_plate_appearances EMA  away_pitches EMA  \
# 0            11.466667                   39.933333        134.266667
# 1             9.613333                   41.115556        152.835556
# 2             6.613630                   35.922963        135.437333
# 3             7.038682                   35.924359        143.035153
# 4            10.137948                   39.266056        118.907828
#
#    away_strikes EMA  away_base_out_runs_added EMA  away_putouts EMA  \
# 0         96.533333                      1.280000         26.600000
# 1        104.275556                     -0.330667         29.986667
# 2         86.649185                      0.687407         27.000000
# 3         87.892055                     -0.329903         27.000000
# 4         92.421844                      1.094862         25.684053
#
#    away_assists EMA  away_innings_pitched EMA  away_homeruns EMA  \
# 0         11.866667                  8.866667           0.266667
# 1         11.706667                  9.964444           0.115556
# 2         10.435852                  9.000000           0.751111
# 3         10.407373                  9.000000           0.830835
# 4          8.211038                  8.561351           1.589094
#
#    away_strikes_by_contact EMA  away_strikes_swinging EMA  \
# 0                    52.133333                  21.533333
# 1                    61.182222                  16.431111
# 2                    48.869926                  11.005333
# 3                    49.497855                  12.595117
# 4                    48.782997                  15.770784
#
#    away_strikes_looking EMA  away_grounded_balls EMA  away_fly_balls EMA  \
# 0                 22.866667                12.533333           12.200000
# 1                 26.928889                10.795556           17.822222
# 2                 26.773926                12.699259           11.141037
# 3                 25.799082                12.738555           11.292601
# 4                 27.868064                13.996580           11.569063
#
#    away_line_drives EMA  away_game_score EMA  away_base_out_runs_saved EMA  \
# 0              4.733333            51.266667                      1.853333
# 1              9.555556            48.884444                      3.215556
# 2              5.282667            62.472593                      2.924148
# 3              5.363425            56.843858                      1.721693
# 4              5.613514            53.059336                      0.031643
#
#    away_batting_average EMA  away_era EMA  target
# 0                  0.282209      5.413534       0
# 1                  0.290629      4.350589       0
# 2                  0.273016      4.912000       1
# 3                  0.239879      4.030791       1
# 4                  0.271515      5.449428       1

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(columns=['target']),
                                                    data.filter(items=['target']).pop('target'),
                                                    test_size = .2)

# %%
# Number of trees in random forest
n_estimators = [i for i in range(100, 1100, 100)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [i for i in range(1, 21)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_param_grid = {'n_estimators': n_estimators,
                      'max_features': max_features,
                      'max_depth': max_depth,
                      'min_samples_split': min_samples_split,
                      'min_samples_leaf': min_samples_leaf,
                      'bootstrap': bootstrap}

# Use the random grid to find the best hyperparameters
# First create the base model to tune
rf = RandomForestClassifier()

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf,
                               param_distributions = random_param_grid,
                               n_iter = 50,
                               cv = 3,
                               verbose = 2,
                               random_state = 42,
                               n_jobs = -1)

# Fit the random search model
rf_random.fit(X_train, y_train)

# %%
rf_random.best_params_

# %%
best_params = {'n_estimators': 100,
               'min_samples_split': 5,
               'min_samples_leaf': 2,
               'max_features': 'sqrt',
               'max_depth': 1,
               'bootstrap': True}

# %%
rf = RandomForestClassifier(**best_params)
rf.fit(X_train, y_train)
rf.score(X_train, y_train)
# Out:
# 0.5329883570504528

# %%
rf.score(X_test, y_test)
# Out:
# 0.5384864165588615
